# %% [markdown]
# # INTRO
#
# In this python notebook, we analyze the data throught tests. We Try to understand if the the

# %%
import pandas as pd
import numpy as np
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

from tools_analysis import *

# %% [markdown]
# ### Definition of input folder

# %%
folder_path = "../study"
stats_path = folder_path + "/stats"

# %% [markdown]
# # Exploration

# %% [markdown]
# # Features names:
# ```json
# metrics = {
#     "dti" : ["FA", "AD", "RD", "MD"],
#     "noddi" : ["icvf", "odi", "fbundle", "fextra", "fintra", "fiso" ],
#     "diamond" : ["wFA", "wMD", "wAD", "wRD", "frac_c0", "frac_c1", "frac_csf", "frac_ctot"],
#     "mf" : ["fvf_f0", "fvf_f1", "frac_f0", "fvf_tot", "wfvf", "frac_f1", "frac_csf", "frac_ftot"]
# }
#
# masks_name = [
#     "thalamus",
#     "hippocampus",
#     "amygdala",
#     "accumbens",
#     "putamen",
#     "pallidum",
#
#     "antThalRadiation",
#     "postThalRadiation-parital",
#     "postThalRadiation-occipital",
#     "supThalRadiation",
#     "infThalRadiation-insula",
#     "infThalRadiation-temporal",
#     "sup-longi-fasci",
#     "inf-longi-fasci",
#     "fornix",
#
#     "acomm",
#     "cc.bodyc",
#     "cc.bodyp",
#     "cc.bodypf",
#     "cc.bodypm",
#     "cc.bodyt",
#     "cc.genu",
#     "cc.rostrum",
#     "cc.splenium",
#     "lh.af",
#     "lh.ar",
#     "lh.atr",
#     "lh.cbd",
#     "lh.cbv",
#     "lh.cst",
#     "lh.emc",
#     "lh.fat",
#     "lh.fx",
#     "lh.ilf",
#     "lh.mlf",
#     "lh.or",
#     "lh.slf1",
#     "lh.slf2",
#     "lh.slf3",
#     "lh.uf",
#     "mcp",
#     "lh.af",
#     "rh.ar",
#     "rh.atr",
#     "rh.cbd",
#     "rh.cbv",
#     "rh.cst",
#     "rh.emc",
#     "rh.fat",
#     "rh.fx",
#     "rh.ilf",
#     "rh.mlf",
#     "rh.or",
#     "rh.slf1",
#     "rh.slf2",
#     "rh.slf3",
#     "rh.uf",
#     "mcp"
#
# ]
# ```
#
# They are composed in the following manner:
#
# [right|left]-[mask_name]\_[metrics]\_[mean|std|skew|kurt|min|max]
#
# [right|left]-[roi_name]\_voxVol
#
# [right|left]-[roiTract_name]\_nTracts

# %%
metrics = ["FA", "AD", "RD", "MD", "icvf", "odi", "fbundle", "fextra", "fintra", "fiso", "wFA", "wMD", "wAD", "wRD", "frac_c0", "frac_c1", "frac_csf", "frac_ctot", "fvf_f0", "fvf_f1", "frac_f0", "fvf_tot", "wfvf", "frac_f1", "frac_csf", "frac_ftot"]


masks_name = [
    "left-thalamus",
    "right-thalamus",
    "left-hippocampus",
    "right-hippocampus",
    "left-amygdala",
    "right-amygdala",
    "left-accumbens",
    "right-accumbens",
    "left-putamen",
    "right-putamen",
    "left-pallidum",
    "right-pallidum",

    "left-antThalRadiation",
    "right-antThalRadiation",
    "left-postThalRadiation-parital",
    "right-postThalRadiation-parital",
    "left-postThalRadiation-occipital",
    "right-postThalRadiation-occipital",
    "left-supThalRadiation",
    "right-supThalRadiation",
    "left-infThalRadiation-insula",
    "right-infThalRadiation-insula",
    "left-infThalRadiation-temporal",
    "right-infThalRadiation-temporal",
    "left-sup-longi-fasci",
    "right-sup-longi-fasci",
    "left-inf-longi-fasci",
    "right-inf-longi-fasci",
    "left-fornix",
    "right-fornix",

    "acomm",
    "cc.bodyc",
    "cc.bodyp",
    "cc.bodypf",
    "cc.bodypm",
    "cc.bodyt",
    "cc.genu",
    "cc.rostrum",
    "cc.splenium",
    "mcp",
    "lh.af",
    "rh.af",
    "lh.ar",
    "rh.ar",
    "lh.atr",
    "rh.atr",
    "lh.cbd",
    "rh.cbd",
    "lh.cbv",
    "rh.cbv",
    "lh.cst",
    "rh.cst",
    "lh.emc",
    "rh.emc",
    "lh.fat",
    "rh.fat",
    "lh.fx",
    "rh.fx",
    "lh.ilf",
    "rh.ilf",
    "lh.mlf",
    "rh.mlf",
    "lh.or",
    "rh.or",
    "lh.slf1",
    "rh.slf1",
    "lh.slf2",
    "rh.slf2",
    "lh.slf3",
    "rh.slf3",
    "lh.uf",
    "rh.uf",
]

# %%
tracula_dict = {
    "acomm": "Anterior commissure",
    "bodyc": "Corpus call. body central",
    "bodyp": "Corpus call. body parietal",
    "bodypf": "Corpus call. body prefrontal",
    "bodypm": "Corpus call. body premotor",
    "bodyt": "Corpus call. body temporal",
    "genu": "Corpus call. genu",
    "rostrum": "Corpus call. rostrum",
    "splenium": "Corpus call. splenium",
    "mcp": "Middle cerebellar peduncle",
    "af": "Arcuate fasciculus",
    "ar": "Acoustic radiation",
    "atr": "Ant. thalamic radiations",
    "cbd": "Cingulum bundle dorsal",
    "cbv": "Cingulum bundle ventral",
    "cst": "Corticospinal tract",
    "emc": "Extreme capsule",
    "fat": "Frontal aslant tract",
    "fx": "Fornix",
    "ilf": "Inf. longi. fasci.",
    "mlf": "Midlle longi. fasci.",
    "or": "Optic radiation",
    "slf1": "Sup. longi. fasci. I",
    "slf2": "Sup. longi. fasci. II",
    "slf3": "Sup. longi. fasci. III",
    "uf": "Uncinate fasciculus",
}

# %% [markdown]
# Here the explanation of some features:
#
# NR-RP/R:
#
# - NR-RP/R == 0 => Non Responder
# - NR-RP/R == 1 => Partial responder or Responder
#
# NR-RP-R:
#
# - NR-RP-R == 0 => Non Responder
# - NR-RP-R == 1 => Partial Responder
# - NR-RP-R == 2 => Responder
#
# epilepsy_type:
#
# - epilepsy_type == 1 => Generalized
# - epilepsy_type == 2 => Focal
#
# AEDs := Anti Epileptic Drugs

# %% [markdown]
# # Analysis on only epileptic patiens without personal data

# %%
# Reading the whole dataset
df = pd.read_csv("%s/dataset_thres1_1.csv" % stats_path, index_col="ID")
print(df.shape)
# # Removing the healty subjects
# df.dropna(axis=0, how="any", inplace=True) 
# print(df.shape)

info = df.columns[:10]
df[info] = df[info].astype(int)

# df = df.drop("VNSLC_16") # remove it because doesn't have the tracts from freesurfer
df = df.dropna(axis=1) # remove NaN features
df = df.drop(df.filter(regex=r'(min|max)'), axis=1) # remove max and min features because are full of imperfections
df = df.drop(df.filter(regex=r'(nTracts)'), axis=1) # remove them beacuse they have an high variability and difficult to interpretare (only kurt)
df = df.loc[:, (abs(df - df.iloc[0]) > 1e-12).any()] # Removing almost constant features
df = df.drop("resp", axis=1)
print(df.shape)
# Out:
# (19, 7528)
# (19, 5117)

# %%
# Reading the whole dataset
df = pd.read_csv("%s/dataset_thres1_1.csv" % stats_path, index_col="ID")
print(df.shape)
# # Removing the healty subjects
# df.dropna(axis=0, how="any", inplace=True) 
# print(df.shape)

info = df.columns[:10]
df[info] = df[info].astype(int)

df = df.drop("VNSLC_16") # remove it because doesn't have the tracts from freesurfer, if I comment it, all the TRACULA tracts will be removed
df = df.dropna(axis=1) # remove NaN features
df = df.drop(df.filter(regex=r'(min|max)'), axis=1) # remove max and min features because are full of imperfections
df = df.drop(df.filter(regex=r'(nTracts)'), axis=1) # remove them beacuse they have an high variability and difficult to interpretare (only kurt)
df = df.loc[:, (abs(df - df.iloc[0]) > 1e-12).any()] # Removing almost constant features
print(df.shape)
# Out:
# (19, 7528)
# (18, 7406)

# %% [markdown]
# Drop the VNLSC_16 subjects and the nan features right cbv, because they are null in the VNSLC_19 subj.

# %%
print(df.value_counts("respPart"))
# Out:
# respPart
# 2    8
# 0    7
# 1    4
# Name: count, dtype: int64

# %% [markdown]
# In our case we have few examples (patients), and so the model will not be so accurate. Then the difference between patients responders and not is different, so our model will be bias influenced.
#
# While if we see the number of samples between responders, partial and not, the number of samples for each class is almost equilibrate.

# %% [markdown]
# Here we want to find which is the best scaling approach, we use a stratified shuffle split to create 100 train and test sets.
# We'll use them to approximate the score of a Logistic regression model. (A basic model for binarized classification task)
# To

# %% [markdown]
# We need to tune the regularization term alpha for the Logistic Regression model. We achive this by using the Logistic RegressionCV by sklear

# %% [markdown]
# # Analysis of info data
#
# - Age = Epilepsy onset age + Epilepsy duration

# %%
df.age == df.epilepsy_onset_age + df.epilepsy_duration
# Out:
# ID
# VNSLC_01     True
# VNSLC_02     True
# VNSLC_03     True
# VNSLC_04     True
# VNSLC_06     True
# VNSLC_07     True
# VNSLC_09     True
# VNSLC_10     True
# VNSLC_11     True
# VNSLC_12     True
# VNSLC_13     True
# VNSLC_14     True
# VNSLC_15     True
# VNSLC_17     True
# VNSLC_18     True
# VNSLC_19    False
# VNSLC_22    False
# VNSLC_23    False
# dtype: bool

# %% [markdown]
# There is a problem in the last three subjects, the sum isn't equal to the age.
#
# Since Age is a compose variable it doens't give any informations for the classification between responder and not.

# %% [markdown]
# # Scaling

# %% [markdown]
# Standard Scaler is always the best for both l1 and l2

# %% [markdown]
# The best are:
# - Normalizer: for F1-score and accuracy
# - Standard Scaler:  for AUC
#
# ##### F1 Score
# F1 score (also known as F-measure, or balanced F-score) is an error metric whose score ranges from 0 to 1, where 0 is the worst and 1 is the best possible score. It provides robust results for imbalanced datasets and evaluates both the recall and precision ability of the model.
#
# ##### AUC
# The score it produces ranges from 0.5 to 1 where 1 is the best score and 0.5 means the model is as good as random.
# The area under this ROC curve, AUC, therefore equates to the model’s ability to predict classes correctly, as a large amount of area would show that the model can achieve a high true positive rate with a correspondingly low false positive rate.
#
# ##### AUC vs F1
# AUC does not perform well on imbalanced datasets which often leads to misleading results, whilst F1 is still able to measure performance objectively when the class balance is skewed.
#
# F1 should be used for situations when you either have an imbalanced dataset or you need to communicate your results to end users, due to the relatively simple definition of F1 in comparison with AUC. AUC should be used when you have a balanced dataset or you don’t want to set a probability boundary between classes, which is required for F1.

# %%
from sklearn.preprocessing import StandardScaler

# Standard Scaler
X_scaled = df.filter(regex=r'mean|std|skew|kurt|voxVol|age|duration') # Take only the contineus value
index, columns = X_scaled.index, X_scaled.columns
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_scaled)
X = pd.DataFrame(X_scaled, index=index, columns=columns)
df_standardized = pd.concat([df["respPart"], X], axis=1)

# %% [markdown]
# # Statistical Test

# %% [markdown]
# ## Relationship between sex and being responder
#
# Explanation here: <br>
# https://machinelearningmastery.com/chi-squared-test-for-machine-learning/ <br>
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chisquare.html <br>
# https://www.scribbr.com/statistics/chi-square-test-of-independence/
#
# Is there a relationship between sex and being respoders?
#
# We use a chi square test since both features are categorical.
#
# First we have to put the two variable in a **Contingency table** between them.
#
# The **Chi-Squared test** is a statistical hypothesis test that assumes (the null hypothesis) that *the observed frequencies for a categorical variable match the expected frequencies for the categorical variable*.
#
# The variables are considered **independent** if *the observed and expected frequencies are similar*, that the levels of the variables do not interact, are not dependent.
#
# ```
# degrees of freedom: (rows - 1) * (cols - 1)
# ```
#
# - **If Statistic >= Critical Value**: significant result, reject null hypothesis (H0), *dependent*.
# - **If Statistic < Critical Value**: not significant result, fail to reject null hypothesis (H0), *independent*.
#
# Or in terms of p-value
#
# - **If p-value <= alpha**: significant result, reject null hypothesis (H0), *dependent*.
# - **If p-value > alpha**: not significant result, fail to reject null hypothesis (H0), *independent*.
#
# For the test to be effective, at **least five observations are required in each cell of the contingency table**, otherwise exact tests (such as **Barnard’s Exact test**) should be used because they do not overreject.
#
# The test is only meaningful when **the dimension of observed is two or more**.

# %%
sexs = ("Male", "Female")
resps = ("Non Responder", "Partial Responder", "Responder")
width = 0.6

fig, ax = plt.subplots()
bottom = np.zeros(2)

M = pd.crosstab(index=df["respPart"], columns=df["sex"]).to_numpy()

for resp_idx, resp in enumerate(resps):

    p = ax.bar(sexs, M[resp_idx, :], width, label=resp, bottom=bottom)
    bottom += M[resp_idx, :]

    ax.bar_label(p, label_type="center")

ax.set_title("Number of responders by sex")
ax.legend()

plt.savefig(folder_path+"/../imgs/stats/sex.png", pad_inches=0, bbox_inches="tight", dpi=150)
plt.show()

# %% [markdown]
# ### Hypotesis definition
#
# From:<br>
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.barnard_exact.html#scipy.stats.barnard_exact
#
# Null hypotesis: no difference between female and male of becoming non responders to VNS
# Alternative hypothesis: female have lower chance of becoming non responders to VNS
#
# probability $p_1$ of being non responder being male will be *greater* than the probability $p_2$ of being non responder being female. (This information can be get even from the graph, because the number of non responderes in males is grather than the female)

# %% [markdown]
# ### Table organization
#
# From the definition:<br>
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.barnard_exact.html#scipy.stats.barnard_exact
#
# In the row should be the output variable (being responder or not), in the columns the input variables (in this case the sex).

# %%
from scipy import stats

def printRes(a, p, method):
    print('significance=%.3f, p=%.3f' % (a, p))
    if p <= a:
        print(method+": Dependent")
    else:
        print(method+": Independent")

alpha = 0.05
obs = pd.crosstab(index=df["respPart"], columns=df["sex"])
obs.index = ("nonResp", "partResp", "Resp")
obs.columns = ("male", "female")
print(obs)
print()

# Chi squared
statistic, p_val, dof, exp_freq = stats.chi2_contingency(obs, True)
printRes(alpha, p_val, "Chi2")
# Out:
#           male  female
# nonResp      4       3
# partResp     3       1
# Resp         2       6
#
# significance=0.050, p=0.212
# Chi2: Independent

# %% [markdown]
# The null hypotesis in not rejected: beeing male doesn't have a greater probability to be non responder

# %% [markdown]
# ## Relationship between benzo and being responder

# %%
cat = ("No", "Yes")
resps = ("Non Responder", "Partial Responder" , "Responder")
width = 0.6

fig, ax = plt.subplots()
bottom = np.zeros(2)

M = pd.crosstab(index=df["respPart"], columns=df["benzo"]).to_numpy()

for resp_idx, resp in enumerate(resps):

    p = ax.bar(cat, M[resp_idx, :], width, label=resp, bottom=bottom)
    bottom += M[resp_idx, :]

    ax.bar_label(p, label_type="center")

ax.set_title("Number of responders by benzo")
ax.legend()

plt.savefig(folder_path+"/../imgs/stats/benzo.png", pad_inches=0, bbox_inches="tight", dpi=150)
plt.show()

# %% [markdown]
# The Alternative hypotesis here will be (from the barplot) that not taking benzo have *less* probability to be non responder.

# %%
from scipy import stats

def printRes(a, p, method):
    print('significance=%.3f, p=%.3f' % (a, p))
    if p <= a:
        print(method+": Dependent")
    else:
        print(method+": Independent")

alpha = 0.05
obs = pd.crosstab(index=df["respPart"], columns=df["benzo"])
obs.index = ("nonResp", "partResp", "Resp")
obs.columns = ("no", "yes")
print(obs)
print()

# Chi squared
statistic, p_val, dof, exp_freq = stats.chi2_contingency(obs, True)
printRes(alpha, p_val, "Chi2")
# Out:
#           no  yes
# nonResp    6    1
# partResp   3    1
# Resp       8    0
#
# significance=0.050, p=0.380
# Chi2: Independent

# %% [markdown]
# Our alternative hypotesis is rejected

# %% [markdown]
# ## Relationship between the type of epilespy and being responder

# %%
cat = ("Generalized", "Focal")
resps = ("Non Responder", "Partial Responder", "Responder")
width = 0.6

fig, ax = plt.subplots()
bottom = np.zeros(2)

M = pd.crosstab(index=df["respPart"], columns=df["epilepsy_type"]).to_numpy()

for resp_idx, resp in enumerate(resps):

    p = ax.bar(cat, M[resp_idx, :], width, label=resp, bottom=bottom)
    bottom += M[resp_idx, :]

    ax.bar_label(p, label_type="center")

ax.set_title("Number of responders by typology")
ax.legend()

plt.savefig(folder_path+"/../imgs/stats/typology.png", pad_inches=0, bbox_inches="tight", dpi=150)
plt.show()

# %% [markdown]
# From the boxplot the alternative hypotesis will be that who has a generalized Epilepsy have *less* probability to be a non responder

# %%
from scipy import stats

def printRes(a, p, method):
    print('significance=%.3f, p=%.3f' % (a, p))
    if p <= a:
        print(method+": Dependent")
    else:
        print(method+": Independent")

alpha = 0.05
obs = pd.crosstab(index=df["respPart"], columns=df["epilepsy_type"])
obs.index = ("nonResp", "partResp", "Resp")
obs.columns = ("Generalized", "Focal")
print(obs)
print()

# Chi squared
statistic, p_val, dof, exp_freq = stats.chi2_contingency(obs, True)
printRes(alpha, p_val, "Chi2")
# Out:
#           Generalized  Focal
# nonResp             0      7
# partResp            0      4
# Resp                3      5
#
# significance=0.050, p=0.086
# Chi2: Independent

# %% [markdown]
# Our alternative hypotesis is rejected

# %% [markdown]
# ## Logistic Regression Relationship between Quantitative data and Categorical

# %% [markdown]
# ### Age

# %%
sns.lmplot(data=df_standardized, x="age", y="resp", logistic=True)
# Out:
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)

# %% [markdown]
# ### Therapy duration

# %%
sns.lmplot(data=df, x="therapy_duration", y="resp", logistic=True)
# Out:
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/families/links.py:198: RuntimeWarning: overflow encountered in exp
#   t = np.exp(-z)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)

# %% [markdown]
# ### Onset Age

# %%
sns.lmplot(data=df, x="epilepsy_onset_age", y="resp", logistic=True)
# Out:
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)

# %% [markdown]
# ### Epilepsy Duration

# %%
sns.lmplot(data=df, x="epilepsy_duration", y="resp", logistic=True)
# Out:
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/statsmodels/genmod/generalized_linear_model.py:1257: PerfectSeparationWarning: Perfect separation or prediction detected, parameter may not be identified
#   warnings.warn(msg, category=PerfectSeparationWarning)

# %% [markdown]
# ## Relation between variables that should be similar

# %%
sns.lmplot(data=df, x="rh.fx_icvf_mean", y="right-fornix_icvf_mean", robust=False)

# %%
sns.residplot(data=df, x="rh.fx_icvf_mean", y="right-fornix_icvf_mean", robust=True)
# Out:
# <Axes: xlabel='rh.fx_icvf_mean', ylabel='right-fornix_icvf_mean'>

# %% [markdown]
# # Comparisons of best region with [METRIC] that has a good separation between responders and not

# %% [markdown]
# For each tract we find the one that has the best FA that can divide the responders from the non responders

# %%
import scipy
from scipy.stats import kruskal, f_oneway, shapiro, levene
from outliers import smirnov_grubbs as grubbs

X = df_standardized.drop(df.filter(regex=r'std|skew|_c0_|_c1_|_f0_|_f1_').columns, axis=1)

def f_test(group1, group2):
    if np.var(group1, ddof=1) >= np.var(group2, ddof=1):
        x = np.array(group1)
        y = np.array(group2)
    else:
        x = np.array(group2)
        y = np.array(group1)
    f = np.var(x, ddof=1)/np.var(y, ddof=1) # calculate F test statistic
    nun = x.size-1 # define degrees of freedom numerator
    dun = y.size-1 # define degrees of freedom denominator
    p_value = 1-scipy.stats.f.cdf(f, nun, dun) # find p-value of F test statistic
    return f, p_value

def countOutliers(group):
    x = np.array(group)
    q1 = np.quantile(x, 0.25)
    q3 = np.quantile(x, 0.75)
    iqr = q3 - q1
    upper = q3 + 1.5*iqr
    lower = q1 - 1.5*iqr

    nOutliers = 0
    nOutliers += (x > upper).sum()
    nOutliers += (x < lower).sum()

    return nOutliers

pval_thresh_5 = 0.05
pval_thresh_1 = 0.01

noResp = X[X["respPart"] == 0]
respPart = X[X["respPart"] == 1]
resp = X[X["respPart"] == 2]

res = {}

for mask in masks_name:
    features = X.filter(regex=f"{mask}").columns
    res[mask] = {}

    # # Checks for parametric test
    # ## shapiro null hypotheis that the data was drawn from a normal distribution
    # p_vals_shap_nonR = {col: shapiro(noResp[col]).pvalue for col in features}
    # p_vals_shap_R = {col: shapiro(resp[col]).pvalue for col in features}
    # p_vals_shap_partR = {col: shapiro(respPart[col]).pvalue for col in features}
    # ## f-test null hypothesis that the data has the same variance
    # p_vals_levene =  {col: levene(noResp[col], respPart[col], resp[col], center="median")[1] for col in features}
    # ## Grubbs' test for outliers
    # bool_grubbs_nonR = {col: countOutliers(noResp[col]) > 0 for col in features}
    # bool_grubbs_R = {col: countOutliers(resp[col]) > 0 for col in features}
    # bool_grubbs_partR = {col: countOutliers(respPart[col]) > 0 for col in features}
    # ## Check all the conditions for the parametric assumptions
    # isParametric = {col: True if p_vals_shap_nonR[col]>=pval_thresh_5 and p_vals_shap_R[col]>=pval_thresh_5 and p_vals_shap_partR[col]>=pval_thresh_5 and p_vals_levene[col]>=pval_thresh_5 and bool_grubbs_nonR[col] == False and bool_grubbs_R[col] == False and bool_grubbs_partR[col] == False else False for col in features}

    # Compute the relative test depending the assumptions
    # p_vals = {col+"-anova" if isParametric[col] else col+"-kruskal": f_oneway(noResp[col], respPart[col], resp[col]).pvalue if isParametric[col] else kruskal(noResp[col], respPart[col], resp[col]).pvalue for col in features}
    p_vals_o = {col: kruskal(noResp[col], respPart[col], resp[col]).pvalue for col in features}

    p_vals = {k:v for k, v in sorted(p_vals_o.items(), key=lambda x: x[1]) if v <= pval_thresh_1}
    res[mask]["0.01"] = p_vals

    p_vals = {k:v for k, v in sorted(p_vals_o.items(), key=lambda x: x[1]) if v > pval_thresh_1 and v <= pval_thresh_5}
    res[mask]["0.05"] = p_vals

# %%
X = df_standardized

features = X.filter(regex=r'mean|std|skew|voxVol|age|duration')
noResp = X[X["respPart"] == 0]
respPart = X[X["respPart"] == 1]
resp = X[X["respPart"] == 2]


p_vals_shap_nonR = {col: shapiro(noResp[col]).pvalue for col in features}
p_vals_shap_R = {col: shapiro(resp[col]).pvalue for col in features}
p_vals_shap_partR = {col: shapiro(respPart[col]).pvalue for col in features}
## f-test null hypothesis that the data has the same variance
p_vals_levene =  {col: levene(noResp[col], respPart[col], resp[col], center="median")[1] for col in features}
## Grubbs' test for outliers
bool_grubbs_nonR = {col: countOutliers(noResp[col]) > 0 for col in features}
bool_grubbs_R = {col: countOutliers(resp[col]) > 0 for col in features}
bool_grubbs_partR = {col: countOutliers(respPart[col]) > 0 for col in features}

nParametrics = 0
for col in features:
    if p_vals_shap_nonR[col]>=pval_thresh and p_vals_shap_partR[col]>=pval_thresh and p_vals_shap_R[col]>=pval_thresh and p_vals_levene[col]>=pval_thresh and bool_grubbs_nonR[col] == False and bool_grubbs_partR[col] == False and bool_grubbs_R[col] == False:
        nParametrics += 1

print(nParametrics)
# Out:
# 1628

# %%
import json

pretty = json.dumps(res, indent=2)

print(pretty)
# Out:
# {
#   "thalamus": {
#     "0.01": {},
#     "0.05": {
#       "right-thalamus_AD_mean": 0.011598715703025415,
#       "right-thalamus_MD_mean": 0.018016858637866683,
#       "left-thalamus_AD_mean": 0.019294555316452414,
#       "right-thalamus_odi_mean": 0.0252922908517819,
#       "right-thalamus_icvf_mean": 0.02720840561904335,
#       "left-thalamus_MD_mean": 0.028528237228586224,
#       "right-thalamus_RD_mean": 0.03154932743929027,
#       "left-thalamus_RD_mean": 0.03179938685482541,
#       "left-thalamus_icvf_mean": 0.035028343029526544
#     }
#   },
#   "hippocampus": {
#     "0.01": {
#       "left-hippocampus_RD_mean": 0.008885733457690972
#     },
#     "0.05": {
#       "left-hippocampus_MD_mean": 0.02672183022833042
#     }
#   },
#   "amygdala": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "accumbens": {
#     "0.01": {},
#     "0.05": {
#       "left-accumbens-area_icvf_mean": 0.01811363651844041,
#       "left-accumbens-area_AD_mean": 0.029593315616610986,
#       "left-accumbens-area_fextra_mean": 0.031790422126174986,
#       "left-accumbens-area_RD_mean": 0.035028343029526544,
#       "right-accumbens-area_AD_mean": 0.03708128599903142,
#       "left-accumbens-area_wAD_mean": 0.04412729773679484
#     }
#   },
#   "putamen": {
#     "0.01": {
#       "left-putamen_AD_mean": 0.007238874983454854
#     },
#     "0.05": {
#       "right-putamen_MD_mean": 0.01717363879136403,
#       "right-putamen_RD_mean": 0.018221206462993862,
#       "right-putamen_AD_mean": 0.02470726634171137,
#       "right-putamen_icvf_mean": 0.028528237228586224,
#       "left-putamen_MD_mean": 0.036305375122105736,
#       "right-putamen_fextra_mean": 0.04030885083176173
#     }
#   },
#   "pallidum": {
#     "0.01": {},
#     "0.05": {
#       "right-pallidum_RD_mean": 0.04360781956039792
#     }
#   },
#   "antThalRadiation": {
#     "0.01": {},
#     "0.05": {
#       "right-antThalRadiation_AD_mean": 0.019835128395070945,
#       "right-antThalRadiation_frac_csf_mf_mean": 0.02268411848488548,
#       "right-antThalRadiation_frac_ftot_mean": 0.02268411848488548,
#       "right-antThalRadiation_MD_mean": 0.02470726634171137,
#       "right-antThalRadiation_odi_mean": 0.02474212257812817,
#       "left-antThalRadiation_odi_mean": 0.025385167668957643,
#       "right-antThalRadiation_fintra_mean": 0.027308318676707136,
#       "right-antThalRadiation_RD_mean": 0.030448171883101127,
#       "left-antThalRadiation_AD_mean": 0.03179938685482541,
#       "left-antThalRadiation_MD_mean": 0.04229992674144947
#     }
#   },
#   "postThalRadiation-parital": {
#     "0.01": {},
#     "0.05": {
#       "right-postThalRadiation-parital_AD_mean": 0.02474212257812817,
#       "left-postThalRadiation-parital_fextra_mean": 0.04581348990914215,
#       "right-postThalRadiation-parital_MD_mean": 0.04880030105449965
#     }
#   },
#   "postThalRadiation-occipital": {
#     "0.01": {},
#     "0.05": {
#       "left-postThalRadiation-occipital_fextra_mean": 0.024839981867729666,
#       "right-postThalRadiation-occipital_icvf_mean": 0.0284078368754099,
#       "left-postThalRadiation-occipital_icvf_mean": 0.030064286904464325,
#       "right-postThalRadiation-occipital_fextra_mean": 0.03246984037283398,
#       "right-postThalRadiation-occipital_fintra_mean": 0.03465504274825114,
#       "right-postThalRadiation-occipital_MD_mean": 0.036551883703790054,
#       "right-postThalRadiation-occipital_RD_mean": 0.04880030105449965
#     }
#   },
#   "supThalRadiation": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "infThalRadiation-insula": {
#     "0.01": {},
#     "0.05": {
#       "left-infThalRadiation-insula_fextra_mean": 0.019398196367740605,
#       "right-infThalRadiation-insula_icvf_mean": 0.019981070576055943,
#       "right-infThalRadiation-insula_AD_mean": 0.024987496999188764,
#       "right-infThalRadiation-insula_MD_mean": 0.025485570310916073,
#       "right-infThalRadiation-insula_fextra_mean": 0.025789167182371973,
#       "left-infThalRadiation-insula_RD_mean": 0.029593315616610986,
#       "left-infThalRadiation-insula_icvf_mean": 0.030064286904464325
#     }
#   },
#   "infThalRadiation-temporal": {
#     "0.01": {},
#     "0.05": {
#       "left-infThalRadiation-temporal_MD_mean": 0.031292410112860186,
#       "right-infThalRadiation-temporal_icvf_mean": 0.031790422126174986,
#       "left-infThalRadiation-temporal_fextra_mean": 0.03809869734058094,
#       "right-infThalRadiation-temporal_MD_mean": 0.03809869734058094,
#       "right-infThalRadiation-temporal_fextra_mean": 0.03809869734058094,
#       "left-infThalRadiation-temporal_icvf_mean": 0.041019693123107825
#     }
#   },
#   "sup-longi-fasci": {
#     "0.01": {},
#     "0.05": {
#       "left-sup-longi-fasci_fbundle_mean": 0.0284078368754099,
#       "left-sup-longi-fasci_fiso_mean": 0.0284078368754099,
#       "right-sup-longi-fasci_fbundle_mean": 0.033729592903634045,
#       "right-sup-longi-fasci_fiso_mean": 0.033729592903634045
#     }
#   },
#   "inf-longi-fasci": {
#     "0.01": {},
#     "0.05": {
#       "right-inf-longi-fasci_fextra_mean": 0.04180196085791773
#     }
#   },
#   "fornix": {
#     "0.01": {
#       "right-fornix_RD_mean": 0.004146741927326671,
#       "right-fornix_MD_mean": 0.005474212950659387,
#       "left-fornix_MD_mean": 0.006360128058062702,
#       "left-fornix_RD_mean": 0.007047550368705353
#     },
#     "0.05": {
#       "right-fornix_AD_mean": 0.0252922908517819,
#       "right-fornix_icvf_mean": 0.035028343029526544,
#       "left-fornix_AD_mean": 0.04422694533710939
#     }
#   },
#   "acomm": {
#     "0.01": {},
#     "0.05": {
#       "acomm_AD_mean": 0.0252922908517819
#     }
#   },
#   "cc.bodyc": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "cc.bodyp": {
#     "0.01": {},
#     "0.05": {
#       "cc.bodypf_AD_mean": 0.0345867120913146,
#       "cc.bodyp_fbundle_mean": 0.04526139796254964,
#       "cc.bodyp_fextra_mean": 0.04526139796254964,
#       "cc.bodyp_fiso_mean": 0.04526139796254964
#     }
#   },
#   "cc.bodypf": {
#     "0.01": {},
#     "0.05": {
#       "cc.bodypf_AD_mean": 0.0345867120913146
#     }
#   },
#   "cc.bodypm": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "cc.bodyt": {
#     "0.01": {},
#     "0.05": {
#       "cc.bodyt_AD_mean": 0.023831474349817316
#     }
#   },
#   "cc.genu": {
#     "0.01": {},
#     "0.05": {
#       "cc.genu_MD_mean": 0.04626783486389385
#     }
#   },
#   "cc.rostrum": {
#     "0.01": {},
#     "0.05": {
#       "cc.rostrum_fbundle_mean": 0.013130720053026136,
#       "cc.rostrum_fiso_mean": 0.015652214707643518,
#       "cc.rostrum_fextra_mean": 0.03694561654569976,
#       "cc.rostrum_MD_mean": 0.03708128599903142,
#       "cc.rostrum_RD_mean": 0.04728331735320011
#     }
#   },
#   "cc.splenium": {
#     "0.01": {},
#     "0.05": {
#       "cc.splenium_frac_csf_d_mean": 0.0472699874700895,
#       "cc.splenium_frac_ctot_mean": 0.0472699874700895
#     }
#   },
#   "lh.af": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.ar": {
#     "0.01": {},
#     "0.05": {
#       "lh.ar_MD_mean": 0.014773154816239111,
#       "lh.ar_fintra_mean": 0.018221206462993862,
#       "lh.ar_icvf_mean": 0.019294555316452414,
#       "lh.ar_AD_mean": 0.023704147096884183,
#       "lh.ar_fextra_mean": 0.02487502533504797
#     }
#   },
#   "lh.atr": {
#     "0.01": {},
#     "0.05": {
#       "lh.atr_AD_mean": 0.025022748576227768
#     }
#   },
#   "lh.cbd": {
#     "0.01": {},
#     "0.05": {
#       "lh.cbd_AD_mean": 0.04581348990914215
#     }
#   },
#   "lh.cbv": {
#     "0.01": {},
#     "0.05": {
#       "lh.cbv_RD_mean": 0.014435513261324293,
#       "lh.cbv_frac_csf_mf_mean": 0.015097394756833414,
#       "lh.cbv_frac_ftot_mean": 0.015097394756833414,
#       "lh.cbv_MD_mean": 0.031002599892108063,
#       "lh.cbv_icvf_mean": 0.036336097547624936,
#       "lh.cbv_fextra_mean": 0.04792759186731076
#     }
#   },
#   "lh.cst": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.emc": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.fat": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.fx": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.ilf": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.mlf": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.or": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.slf1": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.slf2": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.slf3": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "lh.uf": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "mcp": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.ar": {
#     "0.01": {},
#     "0.05": {
#       "rh.ar_AD_mean": 0.02891695818150889,
#       "rh.ar_frac_csf_d_mean": 0.04581348990914215,
#       "rh.ar_frac_ctot_mean": 0.04581348990914215
#     }
#   },
#   "rh.atr": {
#     "0.01": {
#       "rh.atr_AD_mean": 0.005455722476035769
#     },
#     "0.05": {
#       "rh.atr_MD_mean": 0.02807341233431425,
#       "rh.atr_fintra_mean": 0.029187271963682884,
#       "rh.atr_icvf_mean": 0.036582814730419015
#     }
#   },
#   "rh.cbd": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.cbv": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.cst": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.emc": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.fat": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.fx": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.ilf": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.mlf": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.or": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.slf1": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.slf2": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.slf3": {
#     "0.01": {},
#     "0.05": {}
#   },
#   "rh.uf": {
#     "0.01": {},
#     "0.05": {}
#   }
# }

# %%
feature = "inf-longi-fasci_fextra_mean"

cdf = df[[f"left-{feature}", f"right-{feature}", "respPart"]]
# cdf = df[[f"lh.{feature}", f"rh.{feature}", "respPart"]]

mdf = pd.melt(cdf, id_vars="respPart", var_name="side")

ax = sns.boxplot(mdf, x="side", y="value", hue="respPart")
g = sns.stripplot(mdf, x="side", y="value", hue="respPart", palette=["blue", "orange", "green"], legend=False)
ax.set_xticklabels(["left", "right"])
ax.set_ylabel(None)
ax.set_title(feature)
legend = plt.legend()
legend.get_texts()[0].set_text("nonResp")
legend.get_texts()[1].set_text("respPart")
legend.get_texts()[2].set_text("resp")

plt.savefig(f"{folder_path}/../imgs/stats/both-{feature}_partial.png", pad_inches=0, bbox_inches="tight", dpi=150)

# %%
feature = "right-inf-longi-fasci_fextra_mean"
ax = sns.boxplot(df, y=feature, x="respPart")
sns.stripplot(df, y=feature, x="respPart", hue="respPart", palette=["blue", "orange", "green"], legend=False)

ax.set_xlabel("Responder")
ax.set_ylabel(None)
ax.set_title(feature)
ax.set_xticklabels(["nonResp","respPart", "resp"])

plt.savefig(f"{folder_path}/../imgs/stats/{feature}_partial.png", pad_inches=0, bbox_inches="tight", dpi=150)

# %%
from scipy.stats import kruskal

X = df_standardized.drop(df.filter(regex=r'mean|std|skew|_c0_|_c1_|_f0_|_f1_|_csf_mf_|_csf_d_|_fiso_|voxVol').columns, axis=1)

noResp = X[X["respPart"] == 0]
respPart = X[X["respPart"] == 1]
resp = X[X["respPart"] == 2]

table = {}

for mask in masks_name:
    features = X.filter(regex=f"{mask}").columns
    table[mask] = {}
    for col in features:
        res = kruskal(noResp[col], respPart[col], resp[col]).pvalue

        metric = "_".join(col.split("_")[1:])

        table[mask][metric] = res

# %%
table_df = pd.DataFrame(table).transpose()
# remove "_mean", "_std" ... from the metrics
metrics = table_df.columns
new_names = []
for metric in metrics:
    metric = "_".join(metric.split("_")[:-1])
    new_names.append(metric)
table_df.columns = new_names
# sort the metrics in order of model
table_df = table_df[["frac_ftot", "fvf_tot", "wfvf", "frac_ctot", "wFA", "wMD", "wRD", "wAD", "icvf", "fintra", "fextra", "fbundle", "odi", "FA", "MD", "RD", "AD"]]

metrics = table_df.columns # the name of the metrics
indexes = table_df.index # the name of the regions
table_np = table_df.to_numpy()

# Table creation #
line = "& Region & "
for i in range(table_np.shape[1]):
    line += "\\texttt{"
    line += metrics[i].replace("_", "\\_")
    line += "}"
    if i != table_np.shape[1] - 1 :
        line = "{} & ".format(line)
    else:
        line = "{} \\\\ \\midrule ".format(line)
print(line)

print("\\multirow{30}{*}{\\rotatebox[origin=c]{90}{\\texttt{tckgen()} by MRtrix3}}") # 30 are the number of my regions, 90 the degree of rotation
isTracula = False
higlight = False
for i in range(table_np.shape[0]):
    if indexes[i] == "rh.cbv":
        higlight = True

    if "." in indexes[i] or "acomm" in indexes[i] or "mcp" in indexes[i]:
        if isTracula == False:
            # print("\\hline")
            print("\\multirow{42}{*}{\\rotatebox[origin=c]{90}{TRACULA by Freesurfer}}")
        isTracula = True

    line = "& " # start of the line
    if higlight:
        line += "\\cellcolor[HTML]{FEF9E7}"
    line += indexes[i]
    if isTracula:
        roi_name = indexes[i].split(".")
        roi_name = roi_name[0] if len(roi_name) == 1 else roi_name[1]

        line += " (" + tracula_dict[roi_name] + ")"

    line += " & "
    for j in range(table_np.shape[1]):
        pval = table_np[i][j]

        if pval < 0.001:
            line = line + "\\cellcolor[HTML]{2980B9}"
        elif pval < 0.01:
            line = line + "\\cellcolor[HTML]{5499C7}"
        elif pval < 0.05:
            line = line + "\\cellcolor[HTML]{7FB3D5}"
        line = "{}{:.5f}".format(line, pval)
        if pval < 0.001:
            line = line + "***"
        elif pval < 0.01:
            line = line + "**"
        elif pval < 0.05:
            line = line + "*"

        if j != table_np.shape[1] - 1 :
            line = "{} & ".format(line)
        elif i != table_np.shape[0] -1 and not (("." in indexes[i+1] or "acomm" in indexes[i+1] or "mcp" in indexes[i+1]) and isTracula==False):
            line += "\\\\ \\cline{2-19}"
        else:
            line += "\\\\ \\hline"
    print(line)
# Out:
# & Region & \texttt{frac\_ftot} & \texttt{fvf\_tot} & \texttt{wfvf} & \texttt{frac\_ctot} & \texttt{wFA} & \texttt{wMD} & \texttt{wRD} & \texttt{wAD} & \texttt{icvf} & \texttt{fintra} & \texttt{fextra} & \texttt{fbundle} & \texttt{odi} & \texttt{FA} & \texttt{MD} & \texttt{RD} & \texttt{AD} \\ \midrule
# \multirow{30}{*}{\rotatebox[origin=c]{90}{\texttt{tckgen()} by MRtrix3}}
# & left-thalamus & 0.78517 & 0.68923 & 0.95051 & 0.88333 & 0.27404 & 0.28454 & 0.90348 & 0.35586 & 0.07729 & 0.57579 & 0.66255 & 0.97647 & \cellcolor[HTML]{7FB3D5}0.01896* & 0.85127 & 0.13390 & 0.37299 & 0.34017\\ \cline{2-19}
# & right-thalamus & 0.90348 & 0.73933 & 0.84014 & 0.76766 & 0.15475 & 0.09103 & 0.12483 & 0.20905 & 0.10215 & 0.80712 & 0.31140 & 0.65553 & 0.72511 & 0.20286 & 0.19501 & 0.10363 & 0.40744\\ \cline{2-19}
# & left-hippocampus & 0.33677 & 0.83020 & 0.42199 & 0.94754 & 0.55143 & 0.66048 & 0.56401 & 0.77783 & 0.57869 & 0.05608 & 0.77783 & 0.76766 & 0.79110 & 0.79110 & 0.29916 & 0.74352 & 0.35586\\ \cline{2-19}
# & right-hippocampus & 0.17032 & 0.50386 & 0.91947 & 0.32091 & 0.27959 & 0.75857 & 0.22822 & 0.99438 & 0.19834 & 0.11116 & 0.59898 & 0.79110 & 0.21063 & 0.46183 & 0.11521 & 0.83856 & 0.80712\\ \cline{2-19}
# & left-amygdala & 0.62977 & 0.23343 & 0.13390 & 0.66255 & 0.79358 & 0.30618 & 0.15017 & 0.49540 & 0.42199 & 0.58123 & \cellcolor[HTML]{7FB3D5}0.03510* & 0.57869 & 0.91947 & 0.98940 & 0.45952 & 0.23475 & 0.46039\\ \cline{2-19}
# & right-amygdala & 0.69617 & 0.97464 & 0.72511 & 0.67555 & 0.56401 & 0.58452 & 0.94754 & 0.94576 & 0.06345 & \cellcolor[HTML]{7FB3D5}0.04604* & 0.36857 & 0.54218 & 0.07014 & 0.84014 & 0.68923 & 0.18923 & 0.12258\\ \cline{2-19}
# & left-accumbens & 0.82553 & 0.75478 & 0.75857 & 0.88554 & 0.56827 & 0.22201 & 0.52579 & 0.46183 & 0.47089 & 0.62192 & 0.11872 & 0.83020 & 0.42067 & 0.67555 & 0.68966 & 0.24298 & 0.84014\\ \cline{2-19}
# & right-accumbens & 0.13390 & 0.28117 & 0.46971 & 0.73933 & 0.62076 & 0.93165 & 0.97647 & 0.23578 & 0.50386 & 0.38365 & 0.78517 & 0.58452 & 0.12136 & 0.67937 & 0.98940 & 0.68923 & 0.62192\\ \cline{2-19}
# & left-putamen & 0.82553 & 0.16528 & 0.24558 & 0.52579 & 0.47089 & 0.98879 & 0.32516 & 0.63016 & \cellcolor[HTML]{7FB3D5}0.03530* & 0.30907 & 0.07985 & 0.24977 & 0.48314 & 0.57543 & 0.77783 & 0.07729 & 0.09523\\ \cline{2-19}
# & right-putamen & 0.50386 & 0.12052 & 0.22879 & 0.84014 & 0.17586 & 0.54218 & 0.09523 & 0.08152 & 0.24298 & 0.18734 & 0.31851 & 0.99438 & \cellcolor[HTML]{7FB3D5}0.03565* & 0.27959 & 0.74352 & 0.32741 & 0.39537\\ \cline{2-19}
# & left-pallidum & 0.85931 & \cellcolor[HTML]{7FB3D5}0.02817* & \cellcolor[HTML]{7FB3D5}0.02932* & 0.62977 & 0.98879 & 0.54218 & 0.84014 & 0.25950 & \cellcolor[HTML]{7FB3D5}0.02258* & 0.11521 & \cellcolor[HTML]{7FB3D5}0.03143* & 0.67937 & 0.51924 & 0.67937 & 0.46039 & 0.42624 & 0.93165\\ \cline{2-19}
# & right-pallidum & 0.97464 & 0.08480 & 0.23343 & 0.49540 & 0.78517 & 0.36650 & 0.53509 & 0.24558 & 0.74352 & 0.95051 & 0.27559 & 0.98879 & 0.18923 & 0.24070 & 0.21544 & 0.23578 & 0.24977\\ \cline{2-19}
# & left-antThalRadiation & 0.40744 & 0.15592 & 0.13282 & 0.57579 & 0.46971 & 0.81525 & 0.15908 & \cellcolor[HTML]{7FB3D5}0.03619* & 0.42199 & 0.70143 & 0.36673 & 0.77783 & 0.94754 & 0.38365 & 0.09475 & 0.27559 & 0.24805\\ \cline{2-19}
# & right-antThalRadiation & 0.99875 & 0.52579 & 0.76622 & 0.41361 & \cellcolor[HTML]{7FB3D5}0.03264* & 0.30618 & 0.56827 & 0.90348 & 0.58452 & 0.55873 & 0.63333 & 0.69617 & 0.77783 & 0.70143 & 0.34532 & 0.25547 & 0.49540\\ \cline{2-19}
# & left-postThalRadiation-parital & 0.62076 & 0.37229 & 0.27959 & 0.94576 & 0.08701 & 0.85127 & 0.45952 & 0.56401 & 0.28117 & 0.23343 & 0.39537 & 0.88554 & 0.09258 & 0.43898 & 0.68923 & 0.70011 & 0.56260\\ \cline{2-19}
# & right-postThalRadiation-parital & 0.70143 & \cellcolor[HTML]{7FB3D5}0.03786* & \cellcolor[HTML]{7FB3D5}0.02149* & 0.58452 & 0.07338 & 0.46648 & 0.09856 & 0.97647 & 0.51406 & 0.23475 & 0.66923 & 0.82553 & 0.66923 & 0.48314 & 0.22822 & 0.80712 & 0.99875\\ \cline{2-19}
# & left-postThalRadiation-occipital & 0.80712 & 0.62977 & 0.27976 & 0.62076 & 0.91774 & 0.53509 & 0.32516 & 0.73748 & 0.94754 & 0.51406 & 0.21329 & 0.48527 & 0.24481 & 0.91258 & 0.42067 & 0.60236 & 0.15475\\ \cline{2-19}
# & right-postThalRadiation-occipital & 0.42624 & \cellcolor[HTML]{7FB3D5}0.03363* & 0.09258 & 0.84014 & 0.98940 & 0.46971 & 0.68966 & 0.66923 & 0.18734 & 0.52612 & 0.20905 & 0.46648 & 0.12483 & 0.85931 & 0.36193 & 0.95051 & 0.88333\\ \cline{2-19}
# & left-supThalRadiation & 0.76622 & 0.68923 & 0.45952 & 0.56827 & 0.79110 & 0.13585 & 0.41752 & 0.17291 & 0.83020 & 0.23711 & 0.86417 & 0.39611 & 0.42624 & 0.34532 & 0.48893 & 0.49540 & 0.24805\\ \cline{2-19}
# & right-supThalRadiation & 0.72149 & \cellcolor[HTML]{7FB3D5}0.03786* & \cellcolor[HTML]{7FB3D5}0.03619* & 0.38149 & 0.36673 & 0.76622 & 0.43026 & 0.48314 & 0.67937 & 0.76622 & 0.79110 & 0.27559 & 0.48314 & 0.42199 & 0.52612 & 0.46648 & 0.46039\\ \cline{2-19}
# & left-infThalRadiation-insula & 0.37299 & 0.10215 & 0.28241 & 0.32516 & 0.24977 & 0.49540 & 0.24298 & 0.96673 & 0.52612 & 0.90348 & 0.91947 & 0.41361 & 0.05351 & 0.21063 & 0.88554 & 0.66048 & 0.42919\\ \cline{2-19}
# & right-infThalRadiation-insula & 0.32741 & 0.86417 & 0.72511 & 0.95051 & 0.94044 & 0.51827 & 0.74352 & 0.63611 & 0.32741 & 0.82553 & 0.56260 & 0.46648 & 0.51535 & 0.91947 & 0.91258 & 0.95051 & 0.31140\\ \cline{2-19}
# & left-infThalRadiation-temporal & 0.42067 & 0.30618 & 0.27976 & 0.96673 & 0.44591 & 0.99875 & 0.55040 & 0.51406 & 0.15017 & 0.88333 & 0.91947 & 0.96673 & 0.56260 & 0.41361 & 0.68966 & 0.83020 & 0.46039\\ \cline{2-19}
# & right-infThalRadiation-temporal & 0.96916 & 0.87726 & 0.76622 & 0.59337 & 0.28454 & 0.84014 & 0.90859 & 0.38365 & 0.69617 & 0.80712 & 0.90859 & 0.83020 & \cellcolor[HTML]{7FB3D5}0.01866* & 0.80157 & 0.24977 & 0.49540 & 0.59337\\ \cline{2-19}
# & left-sup-longi-fasci & 0.30772 & 0.24298 & 0.19834 & 0.10468 & 0.84014 & 0.07080 & 0.40110 & 0.77783 & 0.56260 & 0.88333 & 0.05038 & 0.20503 & 0.68966 & 0.99438 & 0.13825 & 0.32741 & 0.39216\\ \cline{2-19}
# & right-sup-longi-fasci & 0.13585 & \cellcolor[HTML]{7FB3D5}0.01558* & \cellcolor[HTML]{7FB3D5}0.01558* & 0.48893 & 0.93165 & 0.14436 & 0.22879 & 0.50291 & \cellcolor[HTML]{7FB3D5}0.01775* & 0.09475 & \cellcolor[HTML]{7FB3D5}0.01092* & 0.15475 & 0.50386 & 0.85931 & 0.20503 & 0.09856 & 0.42919\\ \cline{2-19}
# & left-inf-longi-fasci & 0.41752 & 0.52579 & 0.75857 & 0.91258 & 0.58123 & 0.80157 & 0.68966 & 0.51535 & 0.56260 & 0.41752 & 0.20401 & 0.77783 & 0.20905 & 0.29322 & 0.32741 & 0.35922 & 0.37793\\ \cline{2-19}
# & right-inf-longi-fasci & 0.37229 & 0.45694 & 0.27959 & 0.23357 & 0.32516 & 0.59337 & 0.23711 & 0.51827 & 0.36193 & 0.10215 & 0.22879 & 0.40110 & 0.05956 & 0.09564 & 0.17032 & 0.41361 & 0.97464\\ \cline{2-19}
# & left-fornix & 0.24298 & 0.52876 & 0.75478 & 0.13661 & 0.17586 & 0.08459 & 0.47355 & 0.05351 & 0.06138 & 0.17807 & 0.30772 & 0.14876 & 0.23711 & 0.94576 & 0.09637 & 0.27959 & 0.83020\\ \cline{2-19}
# & right-fornix & 0.43898 & 0.87726 & 0.76766 & 0.63611 & 0.66923 & 0.52876 & 0.25547 & 0.70011 & 0.17586 & 0.49540 & 0.68065 & 0.98940 & 0.55873 & 0.33071 & 0.68966 & 0.97647 & 0.48893\\ \hline
# \multirow{42}{*}{\rotatebox[origin=c]{90}{TRACULA by Freesurfer}}
# & acomm (Anterior commissure) & 0.73748 & 0.56401 & 0.98940 & 0.11895 & 0.31851 & 0.20853 & 0.23357 & 0.17807 & 0.77783 & 0.97647 & 0.63333 & 0.19599 & 0.45952 & 0.32741 & \cellcolor[HTML]{7FB3D5}0.01165* & 0.05542 & 0.47089\\ \cline{2-19}
# & cc.bodyc (Corpus call. body central) & 0.79358 & 0.68923 & 0.68923 & 0.55873 & 0.76766 & 0.66048 & 0.62977 & 0.76766 & 0.83020 & 0.35586 & 0.76766 & 0.96673 & 0.52579 & 0.68923 & 0.74352 & 0.56260 & 0.42919\\ \cline{2-19}
# & cc.bodyp (Corpus call. body parietal) & 0.91947 & 0.63016 & 0.79358 & 0.60539 & 0.21994 & 0.96673 & 0.15475 & 0.38365 & 0.87726 & 0.90348 & 0.63333 & 0.56827 & 0.21024 & 0.39537 & 0.94044 & 0.98940 & 0.66048\\ \cline{2-19}
# & cc.bodypf (Corpus call. body prefrontal) & 0.90859 & 0.23357 & 0.24977 & 0.78517 & 0.98879 & 0.42919 & 0.59337 & 0.47355 & 0.38149 & 0.90859 & 0.44340 & 0.99875 & 0.52579 & 0.81525 & 0.88333 & 0.72149 & 0.63333\\ \cline{2-19}
# & cc.bodypm (Corpus call. body premotor) & 0.91947 & 0.63016 & 0.79358 & 0.60539 & 0.21994 & 0.96673 & 0.15475 & 0.38365 & 0.87726 & 0.90348 & 0.63333 & 0.56827 & 0.21024 & 0.39537 & 0.94044 & 0.98940 & 0.66048\\ \cline{2-19}
# & cc.bodyt (Corpus call. body temporal) & 0.27148 & 0.70143 & 0.97464 & 0.29916 & 0.20853 & 0.83020 & 0.50544 & 0.49540 & 0.66923 & 0.85127 & 0.97464 & 0.79110 & 0.27959 & 0.48893 & 0.55873 & 0.39216 & 0.24558\\ \cline{2-19}
# & cc.genu (Corpus call. genu) & 0.57579 & 0.36857 & 0.34532 & 0.21994 & 0.14220 & 0.46039 & 0.13282 & 0.38365 & 0.26877 & 0.75857 & 0.50544 & 0.63333 & 0.35922 & \cellcolor[HTML]{7FB3D5}0.02208* & 0.38558 & 0.13585 & 0.49540\\ \cline{2-19}
# & cc.rostrum (Corpus call. rostrum) & 0.57579 & 0.20905 & 0.21024 & 0.06944 & 0.10234 & 0.27559 & 0.56401 & 0.13390 & 0.79358 & 0.91774 & 0.50291 & 0.17291 & 0.36193 & 0.06453 & 0.39537 & 0.56827 & 0.16363\\ \cline{2-19}
# & cc.splenium (Corpus call. splenium) & 0.36650 & 0.16435 & 0.27976 & 0.08459 & 0.40110 & 0.47089 & 0.17807 & 0.47089 & 0.05401 & 0.59898 & 0.13585 & 0.09469 & 0.77783 & 0.32091 & 0.23475 & 0.99875 & 0.75431\\ \cline{2-19}
# & mcp (Middle cerebellar peduncle) & 0.37229 & 0.14436 & 0.20286 & 0.80157 & 0.32516 & 0.23052 & 0.70011 & 0.24558 & 0.49540 & 0.27148 & 0.52876 & 0.26877 & 0.35922 & 0.18734 & 0.15592 & 0.39537 & 0.90859\\ \cline{2-19}
# & lh.af (Arcuate fasciculus) & 0.99438 & 0.90859 & 0.93165 & 0.08317 & 0.83856 & 0.13059 & 0.81525 & 0.28400 & 0.36673 & 0.57869 & 0.14876 & 0.72511 & 0.86417 & 0.31851 & 0.36857 & 0.80157 & 0.50291\\ \cline{2-19}
# & rh.af (Arcuate fasciculus) & 0.56260 & 0.16363 & 0.15592 & 0.27559 & 0.63333 & 0.40110 & 0.69617 & 0.09931 & 0.38558 & 0.96673 & 0.76766 & 0.35922 & 0.72511 & 0.72511 & 0.51924 & 0.14220 & 0.66048\\ \cline{2-19}
# & lh.ar (Acoustic radiation) & 0.50291 & 0.69617 & 0.79110 & 0.94754 & 0.85931 & 0.37229 & 0.24558 & 0.19834 & 0.17807 & 0.17818 & 0.14536 & 0.70143 & 0.38365 & 0.79358 & \cellcolor[HTML]{7FB3D5}0.03530* & 0.40744 & 0.32516\\ \cline{2-19}
# & rh.ar (Acoustic radiation) & 0.83020 & 0.24977 & 0.27559 & 0.29991 & 0.15563 & 0.45952 & 0.19054 & 0.94754 & 0.41361 & 0.73748 & 0.60236 & \cellcolor[HTML]{7FB3D5}0.04509* & 0.15017 & 0.45694 & 0.23343 & 0.10234 & 0.29322\\ \cline{2-19}
# & lh.atr (Ant. thalamic radiations) & 0.28117 & 0.68923 & 0.63016 & 0.44591 & 0.39537 & 0.57543 & 0.82553 & 0.10686 & 0.21329 & 0.83020 & 0.28117 & 0.18088 & 0.30907 & 0.17807 & 0.23357 & \cellcolor[HTML]{7FB3D5}0.04604* & 0.94576\\ \cline{2-19}
# & rh.atr (Ant. thalamic radiations) & 0.27976 & 0.87726 & 0.44591 & 0.68966 & 0.86417 & 0.29322 & 0.07985 & 0.63016 & 0.35922 & 0.24558 & 0.96673 & 0.57579 & 0.72511 & 0.63333 & 0.49540 & 0.56260 & 0.41752\\ \cline{2-19}
# & lh.cbd (Cingulum bundle dorsal) & 0.49540 & 0.63333 & 0.58123 & 0.60539 & 0.30772 & 0.91258 & 0.09523 & 0.56827 & 0.15017 & 0.25999 & 0.19599 & 0.32516 & 0.28400 & 0.58123 & 0.36857 & 0.12052 & 0.10686\\ \cline{2-19}
# & rh.cbd (Cingulum bundle dorsal) & 0.21666 & 0.77783 & 0.56260 & \cellcolor[HTML]{7FB3D5}0.01482* & 0.44340 & \cellcolor[HTML]{5499C7}0.00662** & 0.72149 & 0.40110 & 0.24558 & 0.78517 & 0.17064 & \cellcolor[HTML]{7FB3D5}0.04604* & 0.36193 & 0.36857 & 0.20401 & 0.32741 & 0.57543\\ \cline{2-19}
# & lh.cbv (Cingulum bundle ventral) & \cellcolor[HTML]{7FB3D5}0.01896* & 0.63016 & 0.68065 & 0.62192 & 0.44591 & 0.11200 & 0.42624 & \cellcolor[HTML]{7FB3D5}0.03961* & 0.79110 & 0.41752 & 0.91258 & 0.31851 & 0.17291 & 0.27559 & 0.27976 & 0.31140 & 0.24977\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.cbv (Cingulum bundle ventral) & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan & nan\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.cst (Corticospinal tract) & 0.85127 & 0.51924 & 0.41361 & 0.68065 & 0.33488 & 0.90348 & 0.19054 & 0.42919 & 0.13390 & \cellcolor[HTML]{7FB3D5}0.03135* & 0.24298 & 0.84014 & 0.41752 & 0.07600 & 0.88333 & 0.28117 & 0.14951\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.cst (Corticospinal tract) & 0.19685 & 0.42067 & 0.42199 & 0.26343 & 0.49540 & 0.34017 & 0.49540 & 0.20905 & 0.86851 & 0.21063 & 0.21063 & 0.09006 & 0.38365 & 0.62977 & 0.41752 & 0.74352 & 0.60539\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.emc (Extreme capsule) & 0.87726 & 0.41752 & 0.55873 & 0.85127 & 0.32192 & 0.29916 & 0.34532 & 0.83020 & 0.24481 & 0.66048 & \cellcolor[HTML]{7FB3D5}0.04028* & 0.76766 & 0.85931 & 0.74352 & \cellcolor[HTML]{7FB3D5}0.03114* & 0.95051 & 0.79358\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.emc (Extreme capsule) & 0.72511 & 0.86417 & 0.81525 & 0.50291 & 0.60539 & 0.10363 & 0.44340 & 0.27976 & 0.11116 & 0.74352 & 0.24977 & 0.90348 & 0.70011 & 0.80712 & 0.19685 & 0.63333 & 0.94576\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.fat (Frontal aslant tract) & \cellcolor[HTML]{7FB3D5}0.04604* & 0.83020 & 0.79110 & 0.56401 & 0.20853 & 0.30772 & 0.34081 & 0.93165 & 0.12258 & 0.63611 & 0.22327 & 0.66923 & 0.17807 & 0.14536 & 0.17807 & 0.57543 & 0.12799\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.fat (Frontal aslant tract) & 0.78517 & 0.09856 & 0.15130 & 0.56260 & 0.18923 & 0.23343 & 0.12799 & 0.36857 & 0.37299 & 0.63333 & 0.39216 & 0.51535 & 0.44675 & 0.21666 & 0.34081 & 0.74352 & 0.80157\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.fx (Fornix) & 0.46183 & 0.78517 & 0.13018 & 0.13315 & 0.12258 & 0.12136 & 0.30907 & 0.24298 & 0.17118 & 0.52876 & 0.91947 & 0.26343 & 0.85127 & 0.90348 & 0.19599 & 0.49540 & 0.48893\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.fx (Fornix) & 0.56226 & 0.18056 & 0.99437 & 0.57836 & 0.08254 & 0.79339 & 0.24035 & 0.80694 & 0.73725 & 0.41714 & 0.77762 & 0.45915 & 0.80694 & 0.57836 & 0.69591 & 0.68940 & 0.98939\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.ilf (Inf. longi. fasci.) & 0.42199 & \cellcolor[HTML]{7FB3D5}0.03653* & 0.09006 & 0.14536 & 0.47355 & 0.16068 & 0.30618 & 0.42199 & 0.63016 & 0.85127 & 0.27559 & 0.50291 & 0.79110 & 0.66048 & 0.50544 & 0.45694 & 0.74352\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.ilf (Inf. longi. fasci.) & 0.17807 & 0.93165 & 0.94754 & 0.24805 & 0.24298 & 0.70011 & 0.06944 & 0.34858 & 0.63333 & 0.94576 & 0.17586 & 0.59898 & 0.29322 & 0.63333 & 0.96673 & 0.57579 & 0.27559\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.mlf (Midlle longi. fasci.) & 0.98879 & 0.95051 & 0.90348 & 0.63333 & 0.80712 & 0.06031 & 0.79358 & 0.56827 & \cellcolor[HTML]{7FB3D5}0.01558* & 0.35922 & \cellcolor[HTML]{7FB3D5}0.03863* & 0.25999 & 0.96673 & 0.78517 & 0.37229 & 0.93165 & 0.19834\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.mlf (Midlle longi. fasci.) & 0.49540 & 0.29322 & 0.12258 & 0.10422 & 0.65553 & 0.22822 & 0.91947 & 0.68923 & 0.52579 & 0.50544 & 0.50544 & 0.07224 & 0.63016 & 0.59337 & 0.96673 & 0.50291 & 0.12136\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.or (Optic radiation) & 0.67555 & 0.11342 & 0.23475 & 0.21666 & 0.63016 & 0.72149 & 0.80712 & 0.61572 & 0.35586 & 0.73933 & 0.12258 & 0.51827 & 0.66923 & 0.90348 & 0.15563 & 0.59898 & 0.05401\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.or (Optic radiation) & 0.90859 & 0.09523 & 0.05038 & 0.78517 & 0.34017 & 0.79110 & 0.09931 & 0.28117 & 0.51924 & 0.25950 & 0.32741 & 0.85931 & 0.16363 & 0.05598 & 0.62192 & 0.69617 & 0.66255\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.slf1 (Sup. longi. fasci. I) & 0.93165 & 0.73748 & 0.75431 & 0.10157 & 0.52579 & 0.28117 & 0.30772 & 0.56401 & 0.30161 & 0.97464 & 0.18734 & 0.26877 & 0.51827 & 0.21024 & 0.57543 & 0.20905 & 0.41752\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.slf1 (Sup. longi. fasci. I) & 0.06138 & 0.11695 & 0.12420 & 0.11895 & 0.06705 & \cellcolor[HTML]{5499C7}0.00415** & 0.17032 & 0.88554 & 0.23343 & 0.27959 & 0.46183 & 0.14536 & 0.07906 & 0.17807 & 0.51827 & 0.17818 & 0.35586\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.slf2 (Sup. longi. fasci. II) & 0.17807 & 0.85127 & 0.83020 & 0.48314 & 0.28400 & 0.62977 & 0.36650 & 0.11695 & 0.11116 & 0.77783 & 0.22822 & \cellcolor[HTML]{7FB3D5}0.04789* & 0.09564 & 0.26343 & 0.77783 & 0.30772 & 0.60539\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.slf2 (Sup. longi. fasci. II) & 0.82553 & 0.20401 & 0.18734 & 0.70011 & 0.17032 & 0.20401 & \cellcolor[HTML]{7FB3D5}0.03961* & 0.79110 & 0.51827 & 0.34081 & \cellcolor[HTML]{7FB3D5}0.02485* & 0.84014 & 0.55143 & 0.22879 & 0.48314 & 0.21994 & 0.40744\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.slf3 (Sup. longi. fasci. III) & 0.56827 & 0.14536 & 0.17552 & 0.20401 & 0.28454 & 0.91774 & 0.14008 & 0.09931 & 0.87726 & 0.14951 & 0.66048 & 0.73748 & 0.20401 & 0.49540 & 0.81525 & 0.33677 & 0.38365\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.slf3 (Sup. longi. fasci. III) & \cellcolor[HTML]{7FB3D5}0.04498* & 0.75857 & 0.56260 & 0.35922 & 0.07676 & \cellcolor[HTML]{5499C7}0.00512** & 0.24558 & 0.05896 & \cellcolor[HTML]{7FB3D5}0.04467* & 0.42624 & 0.17586 & 0.21994 & \cellcolor[HTML]{7FB3D5}0.02574* & \cellcolor[HTML]{7FB3D5}0.02063* & 0.62192 & 0.17586 & 0.08152\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}lh.uf (Uncinate fasciculus) & 0.08480 & 0.32192 & 0.21063 & 0.96916 & \cellcolor[HTML]{7FB3D5}0.02704* & 0.32741 & 0.12166 & 0.14220 & 0.39537 & 0.77783 & 0.57579 & 0.86417 & \cellcolor[HTML]{7FB3D5}0.04840* & 0.11116 & 0.08401 & \cellcolor[HTML]{7FB3D5}0.03408* & 0.37229\\ \cline{2-19}
# & \cellcolor[HTML]{FEF9E7}rh.uf (Uncinate fasciculus) & 0.29322 & 0.07600 & 0.29322 & 0.63611 & 0.10370 & 0.31140 & 0.72511 & 0.08229 & 0.58452 & 0.14536 & 0.16435 & 0.44340 & 0.67937 & 0.17807 & 0.80712 & 0.91947 & 0.80712\\ \hline

# %%
features = df.filter(regex=r'amygdala').columns
alt = "two-sided"

# %%
from scipy.stats import mannwhitneyu

pval_thresh = 0.05

noResp = df[df["resp"] == 0]
resp = df[df["resp"] == 1]

p_vals = {col: mannwhitneyu(noResp[col], resp[col], alternative=alt, method="auto").pvalue for col in features}

p_vals = {k:v for k, v in sorted(p_vals.items(), key=lambda x: x[1]) if v <= pval_thresh}
p_vals
# Out:
# {'right-amygdala_RD_skew': 0.015397184514831573,
#  'left-amygdala_MD_mean': 0.02042483660130719,
#  'left-amygdala_RD_mean': 0.02042483660130719,
#  'left-amygdala_AD_mean': 0.026772247360482657,
#  'left-amygdala_wFA_mean': 0.03456510809451986,
#  'left-amygdala_wfvf_skew': 0.03456510809451986,
#  'left-amygdala_FA_mean': 0.04411764705882353,
#  'right-amygdala_AD_std': 0.04411764705882353}

# %%
from scipy.stats import ttest_ind

pval_thresh = 0.05

noResp = df[df["resp"] == 0]
resp = df[df["resp"] == 1]

p_vals = {col: ttest_ind(noResp[col], resp[col], equal_var=False, alternative=alt).pvalue for col in features}

p_vals = {k:v for k, v in sorted(p_vals.items(), key=lambda x: x[1]) if v <= pval_thresh}
p_vals
# Out:
# {'right-amygdala_RD_skew': 0.024072461599452376,
#  'right-amygdala_wRD_skew': 0.027053454819430056,
#  'left-amygdala_wFA_mean': 0.02900086191896005,
#  'left-amygdala_RD_mean': 0.04040772831044827,
#  'left-amygdala_MD_mean': 0.0423904875249251,
#  'right-amygdala_wMD_skew': 0.04876283456487818}

# %%
from scipy.stats import f_oneway

features = df.columns
pval_thresh = 0.05

noResp = df[df["respPart"] == 0]
respPart = df[df["respPart"] == 1]
resp = df[df["respPart"] == 2]

p_vals = {col: f_oneway(noResp[col], respPart[col], resp[col]).pvalue for col in features}

p_vals = {k:v for k, v in sorted(p_vals.items(), key=lambda x: x[1]) if v <= pval_thresh}
p_vals
# Out:
# /home/michele/anaconda3/envs/dMRI/lib/python3.9/site-packages/scipy/stats/_stats_py.py:3895: ConstantInputWarning: Each of the input arrays is constant;the F statistic is not defined or infinite
#   warnings.warn(stats.ConstantInputWarning(msg))
# {'resp': 0.0,
#  'respPart': 0.0,
#  'lh.fx_icvf_skew': 0.0002699133744376709,
#  'right-fornix_RD_mean': 0.0008508033822484957,
#  'lh.slf3_frac_csf_mf_std': 0.0010316591184765685,
#  'lh.slf3_frac_ftot_std': 0.0010316591184765685,
#  'cc.bodypf_odi_skew': 0.0015965117865141805,
#  'left-fornix_RD_mean': 0.0018366926684175576,
#  'right-fornix_MD_mean': 0.002858886976033674,
#  'left-accumbens-area_frac_c1_std': 0.00324233939297154,
#  'left-antThalRadiation_frac_f1_mean': 0.003411808174494416,
#  'left-pallidum_icvf_std': 0.0036654887899183813,
#  'left-putamen_frac_csf_mf_std': 0.0039628685641786,
#  'left-putamen_frac_ftot_std': 0.0039628685641786,
#  'rh.emc_AD_mean': 0.0040519573028207165,
#  'right-inf-longi-fasci_odi_std': 0.0043260967288880885,
#  'right-antThalRadiation_fextra_std': 0.0043586055421885464,
#  'left-fornix_MD_mean': 0.0045132087943020645,
#  'lh.slf1_RD_skew': 0.004966054905029886,
#  'right-putamen_RD_mean': 0.004966961533793896,
#  'right-putamen_MD_mean': 0.00612883136627113,
#  'right-putamen_frac_c1_skew': 0.006180067405750574,
#  'left-thalamus_RD_std': 0.006252730472991972,
#  'left-pallidum_fextra_std': 0.006254335202563327,
#  'right-pallidum_fiso_std': 0.006273996395271774,
#  'right-pallidum_fbundle_std': 0.0062739979307538775,
#  'left-hippocampus_MD_skew': 0.00669842277633153,
#  'lh.fat_frac_c1_std': 0.007410744164951389,
#  'right-antThalRadiation_AD_mean': 0.00785497995100475,
#  'right-putamen_icvf_mean': 0.008419472109378509,
#  'rh.ar_AD_std': 0.00896024356509237,
#  'left-putamen_AD_mean': 0.009015072879514124,
#  'lh.cst_odi_std': 0.009607203555032468,
#  'lh.slf1_MD_skew': 0.00978789138583555,
#  'lh.fx_MD_mean': 0.009980051734270594,
#  'lh.fx_FA_skew': 0.01027158707955517,
#  'cc.bodypm_frac_f0_std': 0.01037464640516786,
#  'rh.emc_wRD_std': 0.010397442888712402,
#  'left-antThalRadiation_RD_std': 0.010406818626638155,
#  'left-supThalRadiation_AD_skew': 0.010946831420735588,
#  'rh.ilf_frac_c0_skew': 0.011563812971642185,
#  'cc.bodyt_frac_ftot_mean': 0.011756007190369004,
#  'cc.bodyt_frac_csf_mf_mean': 0.01175600719036934,
#  'right-antThalRadiation_frac_f1_mean': 0.01205182825310335,
#  'right-putamen_fextra_mean': 0.012228878490633865,
#  'left-putamen_fextra_skew': 0.012698918656357226,
#  'rh.atr_AD_mean': 0.013411411455789732,
#  'left-thalamus_MD_std': 0.013677509553873247,
#  'lh.slf3_frac_ftot_skew': 0.013783743919816733,
#  'lh.slf3_frac_csf_mf_skew': 0.013783743919817138,
#  'rh.emc_icvf_std': 0.014151643494393885,
#  'lh.mlf_frac_c1_skew': 0.014223509351407364,
#  'lh.fx_fextra_skew': 0.014855349582780132,
#  'right-antThalRadiation_MD_mean': 0.015081218568260678,
#  'lh.uf_fextra_mean': 0.015415000756053492,
#  'left-thalamus_icvf_skew': 0.01541713951832682,
#  'rh.emc_AD_skew': 0.015568254600128518,
#  'lh.fx_AD_mean': 0.015659483854897918,
#  'lh.cst_wRD_std': 0.015836983553162758,
#  'left-infThalRadiation-insula_MD_mean': 0.01592609983466139,
#  'left-antThalRadiation_AD_mean': 0.016225712728946316,
#  'rh.fx_MD_mean': 0.016429725528721253,
#  'left-postThalRadiation-occipital_fextra_mean': 0.01671630132929398,
#  'acomm_MD_mean': 0.016807746224419728,
#  'rh.slf2_fvf_f0_std': 0.016896058550472284,
#  'right-infThalRadiation-insula_MD_mean': 0.016915546574731898,
#  'left-pallidum_fvf_tot_std': 0.016935858470413543,
#  'cc.bodyt_MD_mean': 0.016976955734630584,
#  'right-putamen_AD_mean': 0.017021481319566965,
#  'left-putamen_frac_c1_skew': 0.01729309471077938,
#  'right-putamen_odi_std': 0.017339651608709466,
#  'right-antThalRadiation_RD_std': 0.017556042717952823,
#  'right-hippocampus_frac_c0_skew': 0.01764244856551508,
#  'right-antThalRadiation_frac_ftot_skew': 0.017847677299031823,
#  'right-antThalRadiation_frac_csf_mf_skew': 0.01784767729903274,
#  'rh.ar_fextra_mean': 0.018222024150681828,
#  'left-putamen_MD_mean': 0.018227664048691774,
#  'lh.fx_AD_std': 0.018965593933238534,
#  'left-accumbens-area_icvf_mean': 0.019108198567239176,
#  'lh.uf_MD_mean': 0.020999401959853455,
#  'left-antThalRadiation_MD_skew': 0.02108137031075119,
#  'rh.af_fvf_tot_std': 0.02120507682180348,
#  'epilepsy_duration': 0.021252953453202772,
#  'lh.cbd_fintra_std': 0.021264785567755424,
#  'right-antThalRadiation_icvf_std': 0.02174342500762862,
#  'left-accumbens-area_fextra_mean': 0.02180371122214676,
#  'right-antThalRadiation_fintra_skew': 0.0218593210070251,
#  'right-postThalRadiation-parital_frac_c1_mean': 0.02213898773841949,
#  'left-postThalRadiation-occipital_icvf_mean': 0.022260501046012283,
#  'right-amygdala_RD_skew': 0.022337159784323893,
#  'rh.cst_fextra_skew': 0.022520038624773905,
#  'left-infThalRadiation-insula_icvf_mean': 0.02393822146812778,
#  'rh.emc_frac_f1_mean': 0.02428289428169552,
#  'right-thalamus_AD_mean': 0.02473782338927878,
#  'right-postThalRadiation-occipital_MD_mean': 0.02487022913899313,
#  'lh.fx_frac_c0_skew': 0.02502576290731876,
#  'right-supThalRadiation_frac_ctot_skew': 0.02547673542566863,
#  'right-supThalRadiation_frac_csf_d_skew': 0.025476739167072354,
#  'left-thalamus_AD_mean': 0.025729862048098434,
#  'rh.mlf_frac_f1_mean': 0.025780031602190452,
#  'rh.mlf_MD_mean': 0.025855870529770925,
#  'right-supThalRadiation_fbundle_skew': 0.025996994879819702,
#  'right-supThalRadiation_fiso_skew': 0.025996996681976917,
#  'right-fornix_icvf_mean': 0.026659861519565498,
#  'left-thalamus_MD_mean': 0.026812903700617532,
#  'rh.af_wfvf_std': 0.02683919065046376,
#  'left-infThalRadiation-insula_RD_mean': 0.02688628212124936,
#  'lh.uf_icvf_mean': 0.027229008324478117,
#  'left-postThalRadiation-parital_frac_f1_mean': 0.02778611164319648,
#  'right-fornix_MD_std': 0.027829774854140694,
#  'rh.uf_frac_ftot_skew': 0.027968671461456485,
#  'rh.uf_frac_csf_mf_skew': 0.027968671461456745,
#  'lh.slf1_frac_f0_mean': 0.02806271016963558,
#  'right-accumbens-area_AD_mean': 0.028209350371805844,
#  'right-putamen_wFA_std': 0.028365272145722917,
#  'left-antThalRadiation_frac_c1_mean': 0.02840748873073016,
#  'left-infThalRadiation-insula_fextra_mean': 0.028482977838622418,
#  'cc.bodyt_icvf_mean': 0.028591339168595256,
#  'right-antThalRadiation_frac_c1_skew': 0.028627779117267122,
#  'rh.ar_icvf_mean': 0.02972492308285013,
#  'right-putamen_fextra_skew': 0.029725276452634897,
#  'right-thalamus_odi_mean': 0.029845948067796432,
#  'rh.uf_wfvf_std': 0.0299236714421536,
#  'rh.uf_AD_mean': 0.029983852533892866,
#  'left-antThalRadiation_odi_mean': 0.03002508316086981,
#  'lh.fx_fextra_mean': 0.030089210397026844,
#  'left-infThalRadiation-insula_RD_std': 0.030158760824583346,
#  'left-accumbens-area_icvf_std': 0.030252614827845237,
#  'left-putamen_frac_f1_mean': 0.0302564557385294,
#  'right-antThalRadiation_frac_c1_mean': 0.03031734144204958,
#  'acomm_AD_mean': 0.03034216283347227,
#  'lh.uf_AD_std': 0.030461083872090726,
#  'rh.mlf_fiso_mean': 0.030506189290018998,
#  'rh.mlf_fbundle_mean': 0.030506191651859846,
#  'lh.atr_AD_mean': 0.0305292085343508,
#  'left-postThalRadiation-parital_icvf_mean': 0.030598556061025087,
#  'right-putamen_fvf_f0_skew': 0.030806253155848406,
#  'lh.atr_frac_f1_mean': 0.030927348257913448,
#  'right-postThalRadiation-parital_MD_skew': 0.030942931361419103,
#  'right-putamen_fintra_mean': 0.03123301668628725,
#  'left-pallidum_frac_csf_mf_std': 0.03155996492992042,
#  'left-pallidum_frac_ftot_std': 0.03155996492992042,
#  'left-fornix_icvf_mean': 0.03193402837718714,
#  'right-infThalRadiation-insula_icvf_mean': 0.03198185257827396,
#  'lh.cst_wFA_std': 0.03208241617755196,
#  'right-supThalRadiation_frac_ftot_skew': 0.033268418139284155,
#  'right-supThalRadiation_frac_csf_mf_skew': 0.033268418139284765,
#  'right-hippocampus_MD_skew': 0.033621998318457844,
#  'rh.slf2_MD_skew': 0.03363507057644786,
#  'left-antThalRadiation_RD_skew': 0.03426206707549127,
#  'lh.slf3_fvf_f1_std': 0.03437113299648131,
#  'left-putamen_RD_mean': 0.034753299142542965,
#  'left-infThalRadiation-temporal_icvf_mean': 0.035108661499306464,
#  'right-accumbens-area_icvf_mean': 0.035757719147820895,
#  'lh.uf_AD_mean': 0.035798708868966016,
#  'cc.bodyt_frac_f1_mean': 0.035820194694958306,
#  'right-thalamus_icvf_mean': 0.03606485078277781,
#  'rh.or_AD_mean': 0.03643674122710511,
#  'right-antThalRadiation_frac_ftot_mean': 0.036606493351730406,
#  'right-antThalRadiation_frac_csf_mf_mean': 0.0366064933517306,
#  'left-pallidum_wfvf_std': 0.03689104874947641,
#  'right-thalamus_MD_mean': 0.036917900550311356,
#  'right-accumbens-area_MD_mean': 0.036953622832093504,
#  'cc.genu_AD_mean': 0.037820398307329285,
#  'lh.af_frac_csf_d_skew': 0.038533681815340705,
#  'lh.af_frac_ctot_skew': 0.03853368829550815,
#  'right-putamen_frac_f1_mean': 0.03871036850384406,
#  'rh.atr_frac_f1_mean': 0.038812091535474415,
#  'lh.slf1_frac_c1_std': 0.038949911738198444,
#  'left-accumbens-area_wFA_std': 0.0389550344258932,
#  'cc.splenium_fintra_std': 0.038967189679379344,
#  'rh.fx_odi_skew': 0.03902788483634159,
#  'left-infThalRadiation-temporal_RD_std': 0.03903771007799712,
#  'left-infThalRadiation-temporal_fextra_mean': 0.039233101462320355,
#  'cc.bodyp_fintra_std': 0.03937309922069098,
#  'rh.fx_icvf_mean': 0.039499841524804846,
#  'right-thalamus_icvf_skew': 0.039645660318386095,
#  'lh.ar_icvf_mean': 0.0397379744774147,
#  'left-infThalRadiation-temporal_MD_mean': 0.03990994037101458,
#  'left-antThalRadiation_frac_c0_skew': 0.04021205129058158,
#  'right-putamen_frac_f0_skew': 0.04040856934940432,
#  'right-infThalRadiation-insula_AD_mean': 0.04047376594469421,
#  'left-sup-longi-fasci_fiso_skew': 0.040612478364312816,
#  'left-sup-longi-fasci_fbundle_skew': 0.04061251131698923,
#  'lh.cst_wMD_skew': 0.040754490152678936,
#  'right-postThalRadiation-occipital_icvf_mean': 0.041326930584012454,
#  'right-antThalRadiation_odi_mean': 0.04139631919493828,
#  'cc.bodypf_RD_skew': 0.041514440714850304,
#  'left-accumbens-area_wRD_skew': 0.041904720761367927,
#  'left-accumbens-area_RD_mean': 0.042098693792997736,
#  'left-sup-longi-fasci_fintra_std': 0.04212203875496144,
#  'cc.rostrum_AD_std': 0.042481312297403824,
#  'lh.slf3_frac_f0_mean': 0.04253263064230159,
#  'left-postThalRadiation-parital_MD_mean': 0.04314202039385232,
#  'right-thalamus_wMD_skew': 0.043380942572709746,
#  'right-postThalRadiation-occipital_frac_ftot_mean': 0.04352082668690417,
#  'right-postThalRadiation-occipital_frac_csf_mf_mean': 0.04352082668690455,
#  'right-fornix_AD_mean': 0.04421835474560118,
#  'lh.cst_fvf_f0_skew': 0.04431994006823549,
#  'lh.slf1_frac_f1_mean': 0.04444409908191195,
#  'cc.bodyt_fintra_mean': 0.0447232934075402,
#  'left-pallidum_fiso_std': 0.044862503430955235,
#  'left-pallidum_fbundle_std': 0.04486250954836081,
#  'mcp_fextra_skew': 0.044869175361239716,
#  'rh.af_fvf_f0_std': 0.0450143068513608,
#  'left-fornix_AD_mean': 0.045086881660029526,
#  'rh.slf2_fbundle_mean': 0.04511836549559522,
#  'rh.slf2_fiso_mean': 0.0451183679595149,
#  'lh.emc_MD_mean': 0.045364960692250385,
#  'rh.slf3_odi_std': 0.045597339994726496,
#  'left-thalamus_RD_mean': 0.0456195775462862,
#  'rh.emc_odi_mean': 0.04565576654184975,
#  'lh.or_fvf_f0_skew': 0.04591007487291549,
#  'rh.uf_fvf_tot_std': 0.04597270014170493,
#  'left-accumbens-area_MD_mean': 0.04614852230314431,
#  'right-inf-longi-fasci_FA_std': 0.046679649455838634,
#  'left-antThalRadiation_MD_mean': 0.046711034346380395,
#  'rh.mlf_fextra_mean': 0.046810107904057596,
#  'left-postThalRadiation-parital_fextra_mean': 0.04800853346160309,
#  'right-pallidum_RD_std': 0.0482227986907102,
#  'cc.splenium_MD_skew': 0.04823315927289036,
#  'lh.fx_icvf_mean': 0.048350571974996016,
#  'lh.fx_RD_mean': 0.04851656394230526,
#  'right-postThalRadiation-parital_AD_mean': 0.04897893013292385,
#  'lh.atr_odi_mean': 0.049073523948020566,
#  'left-accumbens-area_wMD_skew': 0.04922247204071126,
#  'lh.slf1_frac_ftot_skew': 0.04978706955586493,
#  'lh.slf1_frac_csf_mf_skew': 0.04978706955586505,
#  'lh.emc_fextra_mean': 0.0499313921455402}

# %%
from scipy.stats import kruskal

features = df.columns
pval_thresh = 0.05

noResp = df[df["respPart"] == 0]
respPart = df[df["respPart"] == 1]
resp = df[df["respPart"] == 2]

p_vals = {col: kruskal(noResp[col], respPart[col], resp[col]).pvalue for col in features}

p_vals = {k:v for k, v in sorted(p_vals.items(), key=lambda x: x[1]) if v <= pval_thresh}
p_vals
# Out:
# {'respPart': 0.00020346836901064455,
#  'resp': 0.00020346836901064563,
#  'lh.fx_icvf_skew': 0.002506866268390786,
#  'lh.slf1_RD_skew': 0.0030711159379943733,
#  'lh.cst_odi_std': 0.0031196011392614345,
#  'left-pallidum_fextra_std': 0.0034986137121953893,
#  'right-inf-longi-fasci_odi_std': 0.0036258222621360662,
#  'right-fornix_RD_mean': 0.00422211730225809,
#  'right-putamen_wFA_std': 0.005124053141987317,
#  'left-pallidum_icvf_std': 0.005646656215278148,
#  'cc.bodypf_odi_skew': 0.006137373506640009,
#  'right-fornix_MD_mean': 0.006137373506640009,
#  'left-accumbens-area_wFA_std': 0.006987313384752869,
#  'left-fornix_MD_mean': 0.007254994411756581,
#  'left-fornix_RD_mean': 0.007254994411756581,
#  'left-putamen_frac_csf_mf_std': 0.0074765040074278,
#  'left-putamen_frac_ftot_std': 0.0074765040074278,
#  'left-antThalRadiation_frac_f1_mean': 0.007575529112428889,
#  'rh.cbd_frac_csf_mf_mean': 0.008369107591561977,
#  'rh.cbd_frac_ftot_mean': 0.008369107591561977,
#  'rh.ar_AD_std': 0.00888796073765363,
#  'right-pallidum_fbundle_std': 0.00888796073765363,
#  'right-pallidum_fiso_std': 0.00888796073765363,
#  'lh.slf1_MD_skew': 0.00935068417641009,
#  'lh.cbd_fintra_std': 0.010408183499900789,
#  'left-accumbens-area_frac_c1_std': 0.010440841720716073,
#  'left-putamen_AD_mean': 0.010440841720716073,
#  'left-antThalRadiation_RD_std': 0.01119985287876994,
#  'right-supThalRadiation_frac_csf_d_skew': 0.011650793934819093,
#  'right-supThalRadiation_frac_ctot_skew': 0.011650793934819093,
#  'lh.af_frac_csf_d_skew': 0.011738724039278085,
#  'lh.af_frac_ctot_skew': 0.011738724039278085,
#  'left-hippocampus_RD_mean': 0.012718957854104703,
#  'right-putamen_fvf_f0_skew': 0.013082678633656579,
#  'right-putamen_frac_c1_skew': 0.013686389823796339,
#  'rh.emc_AD_mean': 0.014033741711308256,
#  'rh.fx_MD_mean': 0.014033741711308256,
#  'right-putamen_FA_std': 0.014681340505706011,
#  'left-antThalRadiation_fextra_std': 0.01481997347952476,
#  'lh.uf_fextra_mean': 0.014903780835394967,
#  'right-antThalRadiation_fextra_std': 0.01566987753974546,
#  'lh.cst_wRD_std': 0.015738756011678966,
#  'rh.af_fvf_tot_std': 0.016341701112461235,
#  'right-putamen_RD_mean': 0.016672661074664225,
#  'right-putamen_frac_f1_mean': 0.016672661074664225,
#  'right-putamen_MD_mean': 0.017053009655799978,
#  'lh.fx_MD_mean': 0.017063697847023843,
#  'right-antThalRadiation_frac_f1_mean': 0.017063697847023843,
#  'lh.slf1_frac_f1_mean': 0.018430758805643137,
#  'right-antThalRadiation_RD_mean': 0.018663173888877345,
#  'lh.uf_MD_mean': 0.01867487127106352,
#  'right-postThalRadiation-parital_RD_std': 0.01867487127106352,
#  'rh.ilf_frac_c0_skew': 0.01895781849382029,
#  'left-thalamus_MD_std': 0.019536638885820815,
#  'right-antThalRadiation_MD_mean': 0.019536638885820815,
#  'cc.bodyt_MD_mean': 0.019634812744501892,
#  'lh.fx_AD_std': 0.019634812744501892,
#  'lh.mlf_frac_c1_skew': 0.020019918642343874,
#  'right-postThalRadiation-parital_frac_c1_mean': 0.020019918642343874,
#  'left-accumbens-area_icvf_mean': 0.02063116709163972,
#  'rh.slf2_fvf_f0_std': 0.02063116709163972,
#  'right-antThalRadiation_RD_std': 0.02063116709163972,
#  'right-putamen_odi_std': 0.02063116709163972,
#  'right-thalamus_AD_mean': 0.02063116709163972,
#  'right-antThalRadiation_icvf_std': 0.021381310166927812,
#  'rh.fat_frac_csf_mf_mean': 0.021855377657448098,
#  'rh.fat_frac_ftot_mean': 0.021855377657448098,
#  'right-antThalRadiation_MD_std': 0.021855377657448098,
#  'lh.fx_fextra_skew': 0.0219102217382585,
#  'left-antThalRadiation_odi_mean': 0.02203412464219774,
#  'lh.emc_fextra_mean': 0.02203412464219774,
#  'right-postThalRadiation-parital_AD_mean': 0.02203412464219774,
#  'left-thalamus_RD_std': 0.022075581120369687,
#  'acomm_MD_mean': 0.022480370293649358,
#  'left-supThalRadiation_AD_skew': 0.022579184949373266,
#  'lh.slf1_frac_f0_mean': 0.024159982165221323,
#  'right-antThalRadiation_AD_mean': 0.024159982165221323,
#  'lh.uf_icvf_mean': 0.02460299198470421,
#  'right-putamen_AD_mean': 0.02460299198470421,
#  'cc.bodyt_frac_csf_mf_mean': 0.025609626387453895,
#  'cc.bodyt_frac_ftot_mean': 0.025609626387453895,
#  'rh.af_FA_std': 0.025609626387453895,
#  'lh.fx_AD_mean': 0.02573831770721134,
#  'right-putamen_icvf_mean': 0.025738317707211526,
#  'rh.cst_fextra_skew': 0.02617744431909034,
#  'left-hippocampus_MD_skew': 0.026177444319090516,
#  'lh.cst_wMD_skew': 0.026774622763487504,
#  'rh.uf_wFA_std': 0.026774622763487504,
#  'right-infThalRadiation-temporal_icvf_mean': 0.026774622763487504,
#  'left-thalamus_icvf_skew': 0.02704438999164294,
#  'rh.atr_AD_mean': 0.02704438999164294,
#  'rh.or_AD_mean': 0.02704438999164294,
#  'left-inf-longi-fasci_FA_std': 0.02719732675765357,
#  'rh.uf_wfvf_std': 0.02719732675765357,
#  'right-postThalRadiation-occipital_icvf_mean': 0.02719732675765357,
#  'right-postThalRadiation-occipital_RD_mean': 0.02760939964216179,
#  'lh.slf2_AD_skew': 0.02816855843469712,
#  'cc.bodyp_fintra_std': 0.02872104030086363,
#  'left-antThalRadiation_AD_mean': 0.028937801844150245,
#  'lh.emc_MD_mean': 0.028937801844150245,
#  'lh.uf_AD_mean': 0.028937801844150245,
#  'rh.emc_wRD_std': 0.028937801844150245,
#  'right-antThalRadiation_fintra_mean': 0.028937801844150245,
#  'cc.bodyt_MD_std': 0.029597951524115585,
#  'rh.ar_icvf_mean': 0.029597951524115585,
#  'right-putamen_fextra_mean': 0.029597951524115585,
#  'cc.bodypf_icvf_std': 0.030674124204018372,
#  'left-putamen_frac_c1_skew': 0.030674124204018372,
#  'left-postThalRadiation-occipital_fextra_mean': 0.03082826520812716,
#  'left-accumbens-area_fextra_mean': 0.03135423243741344,
#  'left-thalamus_AD_mean': 0.032089607420281316,
#  'right-thalamus_MD_mean': 0.032089607420281316,
#  'right-thalamus_icvf_mean': 0.032089607420281316,
#  'lh.uf_frac_f1_mean': 0.032637094662582695,
#  'right-postThalRadiation-occipital_MD_mean': 0.032637094662582695,
#  'right-postThalRadiation-occipital_fintra_mean': 0.032637094662582695,
#  'right-pallidum_RD_std': 0.03306936778417562,
#  'lh.fat_frac_c1_std': 0.0333816352366228,
#  'left-putamen_MD_mean': 0.033570409298038756,
#  'rh.af_fbundle_skew': 0.033570409298038756,
#  'rh.af_fiso_skew': 0.033570409298038756,
#  'rh.mlf_MD_mean': 0.033570409298038756,
#  'left-postThalRadiation-occipital_icvf_mean': 0.03407904220585475,
#  'left-antThalRadiation_RD_skew': 0.034400843812735005,
#  'left-accumbens-area_AD_mean': 0.035097546187210095,
#  'left-fornix_icvf_std': 0.035097546187210095,
#  'mcp_frac_csf_mf_std': 0.035097546187210095,
#  'mcp_frac_ftot_std': 0.035097546187210095,
#  'rh.af_wfvf_std': 0.035097546187210095,
#  'right-fornix_MD_std': 0.035097546187210095,
#  'right-infThalRadiation-temporal_MD_mean': 0.035097546187210095,
#  'cc.bodyt_frac_f1_mean': 0.035296023772041545,
#  'lh.fx_fextra_mean': 0.03529602377204167,
#  'lh.ilf_MD_mean': 0.03529602377204167,
#  'rh.af_fvf_f0_std': 0.03565164822217859,
#  'left-pallidum_frac_csf_mf_std': 0.03653356654872196,
#  'left-pallidum_frac_ftot_std': 0.03653356654872196,
#  'left-accumbens-area_RD_mean': 0.0375547696618502,
#  'rh.uf_frac_csf_mf_std': 0.037554769661850305,
#  'rh.uf_frac_ftot_std': 0.037554769661850305,
#  'cc.bodypf_FA_std': 0.03764900993783321,
#  'lh.fx_FA_skew': 0.03764900993783336,
#  'left-infThalRadiation-insula_RD_mean': 0.037861916120046295,
#  'rh.slf1_fbundle_skew': 0.037861916120046295,
#  'right-antThalRadiation_frac_f1_std': 0.037861916120046295,
#  'cc.genu_frac_f1_std': 0.03786191612004641,
#  'rh.slf1_fiso_skew': 0.03786191612004641,
#  'right-antThalRadiation_frac_c1_skew': 0.03786191612004641,
#  'epilepsy_duration': 0.038375654096327406,
#  'left-putamen_fextra_skew': 0.03841149572926078,
#  'lh.ar_fextra_mean': 0.03841149572926078,
#  'left-inf-longi-fasci_frac_csf_mf_mean': 0.03862871378950484,
#  'left-inf-longi-fasci_frac_ftot_mean': 0.03862871378950484,
#  'right-putamen_fextra_skew': 0.03862871378950484,
#  'lh.atr_frac_c1_mean': 0.039609086029349316,
#  'left-hippocampus_MD_mean': 0.04028486460763714,
#  'left-infThalRadiation-insula_RD_std': 0.04028486460763714,
#  'rh.atr_wAD_mean': 0.04028486460763714,
#  'right-supThalRadiation_fbundle_skew': 0.04028486460763714,
#  'right-supThalRadiation_fiso_skew': 0.04028486460763714,
#  'epilepsy_onset_age': 0.040797293878591566,
#  'left-accumbens-area_wMD_skew': 0.041436880561090655,
#  'left-thalamus_RD_mean': 0.041436880561090655,
#  'right-fornix_icvf_mean': 0.041436880561090655,
#  'right-putamen_frac_f0_skew': 0.041436880561090655,
#  'right-putamen_fvf_tot_std': 0.041436880561090655,
#  'left-pallidum_fvf_tot_std': 0.04151484268404284,
#  'left-postThalRadiation-parital_frac_f1_mean': 0.04151484268404284,
#  'rh.uf_MD_std': 0.04151484268404284,
#  'acomm_AD_mean': 0.04227608012360459,
#  'cc.bodyt_fextra_mean': 0.04227608012360459,
#  'lh.cbv_frac_c1_std': 0.04227608012360459,
#  'mcp_fextra_skew': 0.04227608012360459,
#  'right-supThalRadiation_AD_skew': 0.04227608012360459,
#  'left-putamen_frac_f1_skew': 0.04334902020616771,
#  'right-thalamus_RD_mean': 0.04334902020616771,
#  'right-thalamus_odi_mean': 0.04334902020616771,
#  'left-putamen_frac_f1_mean': 0.04375835636869161,
#  'left-antThalRadiation_frac_c0_skew': 0.043758356368691756,
#  'lh.atr_odi_mean': 0.043758356368691756,
#  'rh.uf_fvf_tot_std': 0.043758356368691756,
#  'rh.slf2_MD_skew': 0.04467255312620004,
#  'cc.rostrum_AD_std': 0.0446725531262002,
#  'right-accumbens-area_AD_mean': 0.0446725531262002,
#  'right-antThalRadiation_odi_mean': 0.0446725531262002,
#  'cc.bodyt_icvf_mean': 0.04498151014125016,
#  'left-sup-longi-fasci_fbundle_skew': 0.04498151014125016,
#  'left-sup-longi-fasci_fiso_skew': 0.04498151014125016,
#  'right-infThalRadiation-insula_fextra_mean': 0.04498151014125016,
#  'left-thalamus_icvf_mean': 0.04509438714643507,
#  'lh.cst_fvf_f0_skew': 0.04509438714643507,
#  'rh.emc_wAD_mean': 0.04509438714643507,
#  'rh.mlf_frac_f1_mean': 0.04509438714643507,
#  'rh.mlf_wMD_mean': 0.04509438714643507,
#  'right-antThalRadiation_frac_csf_mf_mean': 0.04509438714643507,
#  'right-antThalRadiation_frac_ftot_mean': 0.04509438714643507,
#  'right-pallidum_RD_mean': 0.04509438714643507,
#  'right-sup-longi-fasci_fextra_skew': 0.04509438714643507,
#  'lh.fx_frac_c0_skew': 0.045349397140653905,
#  'left-inf-longi-fasci_odi_std': 0.04603649617273763,
#  'lh.cst_wFA_std': 0.04603649617273763,
#  'lh.ilf_FA_std': 0.04603649617273763,
#  'right-hippocampus_frac_c0_skew': 0.04603649617273763,
#  'cc.bodypf_RD_std': 0.04673400559855694,
#  'cc.bodypf_RD_skew': 0.04789006928888887,
#  'left-infThalRadiation-insula_icvf_mean': 0.048251502064945245,
#  'left-infThalRadiation-temporal_MD_mean': 0.048251502064945245,
#  'left-infThalRadiation-temporal_icvf_mean': 0.048251502064945245,
#  'left-putamen_fvf_f0_skew': 0.048251502064945245,
#  'left-thalamus_MD_mean': 0.048251502064945245,
#  'right-thalamus_icvf_skew': 0.048251502064945245,
#  'right-thalamus_wMD_skew': 0.048251502064945245,
#  'lh.atr_AD_mean': 0.04840290295148063,
#  'right-infThalRadiation-insula_MD_mean': 0.04840290295148063,
#  'right-sup-longi-fasci_fbundle_mean': 0.04840290295148063,
#  'right-sup-longi-fasci_fiso_mean': 0.04840290295148063,
#  'cc.bodypm_frac_f0_std': 0.04840290295148081,
#  'right-inf-longi-fasci_frac_f1_mean': 0.04840290295148081,
#  'left-sup-longi-fasci_fiso_mean': 0.04922871460785927,
#  'left-antThalRadiation_frac_c1_mean': 0.04922871460785942,
#  'left-sup-longi-fasci_fbundle_mean': 0.04922871460785942}

# %% [markdown]
# # Simple Exploratory Data Analysis

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

X = df

pca = PCA(
    n_components=2,
    svd_solver="full",
)
Y_pca = pd.DataFrame(pca.fit_transform(X), index=df.index, columns=["c0", "c1"])
Y_pca = pd.concat([Y_pca, df["resp"]], axis=1)

sns.scatterplot(Y_pca, x="c0", y="c1", hue="resp")

for perplexity in range(2, df.shape[0]):

    tSNE = TSNE(
        n_components=2,
        perplexity=perplexity, # to change
        learning_rate="auto", # epslon
        n_iter=5000, # per essere sicuro delle convergenza
        #n_iter_without_progress=3000, # per stopparlo prima
        init="pca",
        method="exact", # it's slowert but out dataset is small so we can affort it
        n_jobs=-1, # run in parallel
    )
    Y_tSNE = pd.DataFrame(tSNE.fit_transform(X),index=df.index, columns=["c0", "c1"])
    Y_tSNE = pd.concat([Y_tSNE, df["resp"]], axis=1)

    plt.figure()
    sns.scatterplot(Y_tSNE, x="c0", y="c1", hue="resp")

# %%
sns.displot(df, x="left-thalamus_odi_mean", hue="resp", kde=True)

# %%
sns.jointplot(
    data=df,
    x='right-fornix_icvf_mean', y='left-fornix_icvf_mean', hue="resp",
    kind="kde"
)

# %%
toPlot = ['left-accumbens-area_frac_c0_mean', 'right-fornix_icvf_kurt']
sns.pairplot(df, hue="resp", x_vars=toPlot, y_vars=toPlot)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

a = df
features = ['left-inf-longi-fasci_nTracts', 'left-thalamus-Insula_nTracts', 'right-inf-longi-fasci_nTracts']
x = a[features[0]]
y = a[features[1]]
z = a[features[2]]
labs = a["resp"]

# axes instance
fig = plt.figure(figsize=(6,6))
ax = Axes3D(fig, auto_add_to_figure=False)
fig.add_axes(ax)

# get colormap from seaborn
cmap = ListedColormap(sns.color_palette("husl", 2).as_hex())

# plot
sc = ax.scatter(x, y, z, s=40, c=labs, marker='o', cmap=cmap, alpha=1)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

# legend
plt.legend(*sc.legend_elements(), bbox_to_anchor=(1.05, 1), loc=2)
